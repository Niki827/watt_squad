# %% [markdown]
# # Overview of our RNN

# %% [markdown]
# ## Input Data

# %% [markdown]
# - **n_sequences = 1** (one location for now)
# - **n_observations = 9515**
# - **n_features = count once we have the pipeline ready**

# %% [markdown]
# ## Shape of our prediction model

# %% [markdown]
# - Predict **841 consecutive observations** for testing period
# - Use multiple input features and multiple output targets
# - Input features: rainfall, sun light etc.
# - Output targets: wind production, pv production, consumption

# %% [markdown]
# ### Shape of X

# %% [markdown]
# - **(1, 9515, n_features)**
# - 1 corresponds to the number of sequences (one location for now)
# - 9515 corresponds to the number of observations that we have as input in the train dataset
# - n_features will be counted once we have pipeline ready

# %% [markdown]
# ### Shape of Y

# %% [markdown]
# - **(1, 841, n_features)**
# - 1 corresponds to the number of sequences (one location for now)
# - 841 corresponds to the number of observations in the test dataset that we want to predict
# - n_features will be counted once we have pipeline ready

# %% [markdown]
# # Coding from Lecture

# %% [markdown]
# ## Coding the model

# %%
# # 0- Imports
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.optimizers import Adam
# from tensorflow.keras import layers

# # 1- RNN Architecture
# model = Sequential()
# model.add(layers.SimpleRNN(units=10, activation='tanh', input_shape=(9515,3)))
# model.add(layers.Dense(3, activation="linear"))

# # 2- Compilation
# model.compile(loss='mse', 
#               optimizer=Adam(lr=0.5)) # very high lr so we can converge with such a small dataset

# # 3- Fit
# model.fit(X, y, epochs=10000, verbose=0)

# # 4- Predict
# model.predict(X) # One prediction per city

# %% [markdown]
# ### Alternative compile function from the challenges

# %%
model.compile(loss='mse', optimizer='rmsprop', metrics=['mse'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 model.compile(loss='mse', optimizer='rmsprop', metrics=['mse'])
#
# NameError: name 'model' is not defined

# %% [markdown]
# ## Alternative model from challenges

# %%
from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras import optimizers, metrics
from tensorflow.keras.regularizers import L1L2
from tensorflow.keras.layers.experimental.preprocessing import Normalization

def init_model(X_train, y_train):
    
    # YOUR CODE HERE
    
    # 0 - Normalization
    # ======================    
    normalizer = Normalization()   # Instantiate a normalizer (Standard Scaler)
    normalizer.adapt(X_train)      # trains the normalizer
    
    # 1 - RNN architecture
    # ======================    
    model = models.Sequential()
    ## 1.0 - All the rows will be standardized through the already adapted normalization layer
    model.add(normalizer)
    ## 1.1 - Recurrent Layer
    model.add(layers.LSTM(64, 
                          activation='tanh', 
                          return_sequences = False,
                          kernel_regularizer=L1L2(l1=0.05, l2=0.05),
                          ))
    ## 1.2 - Predictive Dense Layers
    output_length = y_train.shape[1]
    model.add(layers.Dense(output_length, activation='linear'))  

    # 2 - Compiler
    # ======================    
    adam = optimizers.Adam(learning_rate=0.02)    
    model.compile(loss='mse', optimizer=adam, metrics=["mae"])
    
    return model

# %% [markdown]
# ## Coding the EarlyStopper

# %%
from tensorflow.keras.callbacks import EarlyStopping
EarlyStopper = EarlyStopping(
    monitor='val_loss',
    patience=5,
    verbose=0,
    restore_best_weights=True
)

# %% [markdown]
# ## Coding the evaluation

# %%
model.evaluate(X_test, y_test)

# %% [markdown]
# # Understanding the code and parameters

# %% [markdown]
# ## input_shape

# %% [markdown]
# - input_shape=(9515,3)
# - 9515 corresponds to the number of days
# - 3 we have to replace with the number of features once we have decided on them

# %% [markdown]
# ## Dense Layer

# %% [markdown]
# model.add(layers.Dense(3, activation="linear"))
# - We have 3 targets to predict (solar production, wind production and consumption)
# - We have a linear activation function as we want to predict continuous variables
# - Ensure that the dimensions of x and y match up, otherwise use np.expand_dims()

# %% [markdown]
# # Parameters to optimize

# %% [markdown]
# ## Increase the number of units

# %% [markdown]
# - units=2
# - We can increase the number of units such that the model 'learns' more quirks of the data.
# - The number of units can be seen as the number of memories about featuresmaintained in parallel.
# - **I increased the number of units to 10**

# %% [markdown]
# ## Add another dense layer

# %%
# model.add(layers.SimpleRNN(units=2, activation='tanh', input_shape=(4,3)))
# model.add(layers.Dense(2, activation="linear"))
# model.add(layers.Dense(3, activation="linear"))

# %% [markdown]
# ## Add another RNN layer

# %%
# model.add(layers.SimpleRNN(units=2, return_sequences = True, etc.)))
# model.add(layers.SimpleRNN(units=2, activation='tanh'))
# model.add(layers.Dense(1, activation="linear"))

# %% [markdown]
# ❗️ Take note! ❗️ We've added return_sequences = True

# %% [markdown]
# - We do this so that the units of each hidden state is returned instead of just the units of the last hidden state
# - That is important as the new RNN layer will require sequential data as input again. Therefore, it requires the units from multiple hidden states from the previous RNN layer.

# %% [markdown]
# ## Use LSTM and GRU to improve memory

# %% [markdown]
# - Problem with normal RNNs: vanishing gradient
# - They only pass the last hidden state to make a prediction
# - Therefore, they suffer from a problem called: vanishing gradient
# - Means: the model does not have a very good memory of what happened at the beginning of the time series
# - Often, the last values of the time series have a greater impact on the hidden state that gets passed to the next layer

# %%
# model.add(layers.LSTM(units=5, activation='tanh', input_shape=(4,3)))
# model.add(layers.Dense(10, activation="linear"))
# model.add(layers.Dense(1, activation="linear"))

# %% [markdown]
# # Importing preprocessed data

# %%
import pandas as pd
import numpy as np

from sklearn.pipeline import make_pipeline
from sklearn.pipeline import make_union
from sklearn.compose import make_column_transformer

from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import MinMaxScaler

#Reading Raw X_train
X_train = pd.read_csv('/Users/niki/code/Niki827/watt_squad/raw_data/train.csv')
X_test = pd.read_csv('/Users/niki/code/Niki827/watt_squad/raw_data/test.csv')

#Log columns
f_logs = [
    'precip_1h:mm',
    'prob_precip_1h:p',
    'clear_sky_rad:W',
    'clear_sky_energy_1h:J',
    'diffuse_rad:W',
    'diffuse_rad_1h:Wh',
    'direct_rad:W',
    'direct_rad_1h:Wh',
    'global_rad:W',
    'global_rad_1h:Wh',
    'wind_speed_2m:ms',
    'wind_speed_10m:ms',
    'wind_speed_50m:ms',
    'wind_speed_100m:ms'
]

epsilon = 1e-5

for f in f_logs:
    X_train[f] = np.log(X_train[f] + epsilon)
    X_test[f] = np.log(X_test[f] + epsilon)

# Converting time to datetime
# We might have done that before already
X_train['time']= pd.to_datetime(X_train['time'])
X_test['time']= pd.to_datetime(X_test['time'])

#the following two steps creates new columns to get the input for the sine & cosine columns
#creating columns indicating the hour and the month
X_train['hour'] = X_train['time'].dt.hour
X_train['month'] = X_train['time'].dt.month

X_test['hour'] = X_test['time'].dt.hour
X_test['month'] = X_test['time'].dt.month

#creating column indicating the season
def assign_season(month):
    if month in [3, 4, 5]:
        return 1  # Spring
    elif month in [6, 7, 8]:
        return 2  # Summer
    elif month in [9, 10, 11]:
        return 3  # Fall
    else:  # December, January, February
        return 4  # Winter

# X_train
X_train['season'] = X_train['month'].apply(assign_season)

X_train['hour_sine'] = np.sin(2 * np.pi * X_train['hour'] / 24)
X_train['hour_cosine'] = np.cos(2 * np.pi * X_train['hour'] / 24)

X_train['month_sine'] = np.sin(2 * np.pi * X_train['month'] / 12)
X_train['month_cosine'] = np.cos(2 * np.pi * X_train['month'] / 12)

X_train['season_sine'] = np.sin(2 * np.pi * X_train['season'] / 4)
X_train['season_cosine'] = np.cos(2 * np.pi * X_train['season'] / 4)

X_train = X_train.drop(columns = ['hour', 'month', 'season'])

# X_test
X_test['season'] = X_test['month'].apply(assign_season)

X_test['hour_sine'] = np.sin(2 * np.pi * X_test['hour'] / 24)
X_test['hour_cosine'] = np.cos(2 * np.pi * X_test['hour'] / 24)

X_test['month_sine'] = np.sin(2 * np.pi * X_test['month'] / 12)
X_test['month_cosine'] = np.cos(2 * np.pi * X_test['month'] / 12)

X_test['season_sine'] = np.sin(2 * np.pi * X_test['season'] / 4)
X_test['season_cosine'] = np.cos(2 * np.pi * X_test['season'] / 4)

X_test = X_test.drop(columns = ['hour', 'month', 'season'])

# Cyclic features
cyclical_features = ['sun_azimuth:d', 'wind_dir_2m:d', 'wind_dir_10m:d', 'wind_dir_50m:d', 'wind_dir_100m:d']
degrees = 360

for cyclical_feature in cyclical_features:
    sin_column_name = f'sin_{cyclical_feature}'
    cos_column_name = f'cos_{cyclical_feature}'
    X_train[sin_column_name] = np.sin(2 * np.pi * X_train[cyclical_feature]/2)
    X_train[cos_column_name] = np.cos(2 * np.pi * X_train[cyclical_feature]/degrees)
    X_test[sin_column_name] = np.sin(2 * np.pi * X_test[cyclical_feature]/2)
    X_test[cos_column_name] = np.cos(2 * np.pi * X_test[cyclical_feature]/degrees)

X_train = X_train.drop(columns=cyclical_features)
X_test = X_test.drop(columns=cyclical_features)

# targets = ['pv_production', 'wind_production', 'consumption']
f_minmax = [
    'hour_sine',
    'hour_cosine',
    'month_sine',
    'month_cosine',
    'season_sine',
    'season_cosine',
    'precip_1h:mm',
    'prob_precip_1h:p',
    'clear_sky_rad:W',
    'clear_sky_energy_1h:J',
    'diffuse_rad:W',
    'diffuse_rad_1h:Wh',
    'direct_rad:W',
    'direct_rad_1h:Wh',
    'global_rad:W',
    'global_rad_1h:Wh',
    'sunshine_duration_1h:min',
    'low_cloud_cover:p',
    'medium_cloud_cover:p',
    'high_cloud_cover:p',
    'total_cloud_cover:p',
    'effective_cloud_cover:p',
    'sin_sun_azimuth:d',
    'cos_sun_azimuth:d',
    'sin_wind_dir_2m:d',
    'cos_wind_dir_2m:d',
    'sin_wind_dir_10m:d',
    'cos_wind_dir_10m:d',
    'sin_wind_dir_50m:d',
    'cos_wind_dir_50m:d',
    'sin_wind_dir_100m:d',
    'cos_wind_dir_100m:d',
    'relative_humidity_2m:p',
    'relative_humidity_10m:p',
    'relative_humidity_50m:p',
    'relative_humidity_100m:p',
    'dew_point_2m:C',
    'dew_point_10m:C',
    'dew_point_50m:C',
    'dew_point_100m:C',
    'temp'
]
f_standard = ['sun_elevation:d']
f_robust = [
    't_10m:C',
    't_50m:C',
    't_100m:C',
    'wind_speed_2m:ms',
    'wind_speed_10m:ms',
    'wind_speed_50m:ms',
    'wind_speed_100m:ms'
]

f_ohe = ['precip_type:idx']

# other = ['spot_market_price']

# target
y = X_train[['pv_production', 'wind_production', 'consumption']]
# features
X_train = X_train.drop(columns=['time', 'pv_production', 'wind_production', 'consumption', 'spot_market_price'])
X_test = X_test.drop(columns=['time', 'pv_production', 'wind_production', 'consumption', 'spot_market_price'])

# Preprocessing Pipeline
minmax_scaler = MinMaxScaler()
standard_scaler = StandardScaler()
cat_transformer = OneHotEncoder()
robust_scaler = RobustScaler()

preproc_basic = make_column_transformer(
    (minmax_scaler, f_minmax ),
    (standard_scaler, f_standard),
    (robust_scaler, f_robust),
    (cat_transformer, f_ohe),
    remainder='passthrough'
)
# Train X
X_train_transformed = preproc_basic.fit_transform(X_train)

# Adding Column names
X_train_transformed = pd.DataFrame(
    X_train_transformed,
    columns=preproc_basic.get_feature_names_out()
)
# Test x
X_test_transformed = preproc_basic.transform(X_test)
# Adding Column names
X_test_transformed = pd.DataFrame(
    X_test_transformed,
    columns=preproc_basic.get_feature_names_out()
)

# %% [markdown]
# # Predicting Solar Production using XGBoost

# %% [markdown]
# ## Importing non preprocessed data

# %%
train_data = pd.read_csv('/Users/niki/code/Niki827/watt_squad/raw_data/train.csv')
test_data = pd.read_csv('/Users/niki/code/Niki827/watt_squad/raw_data/test.csv')

# %%
train_data
# Out:
#                      time  pv_production  wind_production  consumption  \
# 0     2020-01-01 13:00:00            0.0            40.59    26.514689
# 1     2020-01-01 14:00:00            0.0            67.86    28.326960
# 2     2020-01-01 15:00:00            0.0           116.68    23.682207
# 3     2020-01-01 16:00:00            0.0           120.22    25.354782
# 4     2020-01-01 17:00:00            0.0           109.86    23.861942
# ...                   ...            ...              ...          ...
# 9510  2021-01-31 19:00:00            0.0            21.98    44.422658
# 9511  2021-01-31 20:00:00            0.0             9.60    45.167707
# 9512  2021-01-31 21:00:00            0.0            22.61    32.476198
# 9513  2021-01-31 22:00:00            0.0            21.70    28.561791
# 9514  2021-01-31 23:00:00            0.0            20.07    27.148858
#
#       spot_market_price  precip_1h:mm  precip_type:idx  prob_precip_1h:p  \
# 0               0.28969           0.0              0.0               1.0
# 1               0.29561           0.0              0.0               1.0
# 2               0.30044           0.0              0.0               1.0
# 3               0.29975           0.0              0.0               1.0
# 4               0.29650           0.0              0.0               1.0
# ...                 ...           ...              ...               ...
# 9510            0.60243           0.0              0.0               1.0
# 9511            0.53335           0.0              0.0               1.0
# 9512            0.51195           0.0              0.0               1.0
# 9513            0.47122           0.0              0.0               1.0
# 9514            0.44203           0.0              0.0               1.0
#
#       clear_sky_rad:W  clear_sky_energy_1h:J  ...  t_50m:C  \
# 0                10.0                64826.0  ...      8.4
# 1                 0.0                 8961.1  ...      8.4
# 2                 0.0                    0.0  ...      8.5
# 3                 0.0                    0.0  ...      8.4
# 4                 0.0                    0.0  ...      7.2
# ...               ...                    ...  ...      ...
# 9510              0.0                    0.0  ...     -3.2
# 9511              0.0                    0.0  ...     -3.5
# 9512              0.0                    0.0  ...     -3.6
# 9513              0.0                    0.0  ...     -3.7
# 9514              0.0                    0.0  ...     -4.0
#
#       relative_humidity_50m:p  dew_point_50m:C  wind_speed_50m:ms  \
# 0                        60.7              1.3                8.4
# 1                        61.6              1.5                8.0
# 2                        60.3              1.3                9.6
# 3                        63.9              2.0               12.1
# 4                        78.9              3.8               11.7
# ...                       ...              ...                ...
# 9510                     93.1             -4.2                4.8
# 9511                     94.1             -4.3                4.9
# 9512                     93.0             -4.6                4.7
# 9513                     92.1             -4.8                4.5
# 9514                     92.2             -5.0                4.3
#
#       wind_dir_50m:d  t_100m:C  relative_humidity_100m:p  dew_point_100m:C  \
# 0              246.3       8.3                      60.3               1.0
# 1              252.3       8.4                      60.7               1.2
# 2              254.1       8.4                      59.6               1.0
# 3              254.6       8.3                      63.4               1.7
# 4              249.5       7.1                      77.9               3.5
# ...              ...       ...                       ...               ...
# 9510           231.2      -3.1                      91.6              -4.3
# 9511           224.9      -3.3                      92.1              -4.4
# 9512           224.5      -3.3                      90.6              -4.6
# 9513           222.8      -3.4                      89.5              -4.9
# 9514           218.7      -3.5                      89.3              -5.0
#
#       wind_speed_100m:ms  wind_dir_100m:d
# 0                   10.4            247.3
# 1                   10.0            252.1
# 2                   11.7            253.8
# 3                   14.3            254.2
# 4                   13.9            249.7
# ...                  ...              ...
# 9510                 6.0            238.3
# 9511                 6.2            231.8
# 9512                 6.0            231.7
# 9513                 5.8            231.1
# 9514                 5.6            227.2
#
# [9515 rows x 44 columns]

# %% [markdown]
# ### Creating X_train, y_train, X_test, y_test

# %%
X_train = train_data[['precip_1h:mm', 'clear_sky_rad:W', 'diffuse_rad:W', 'sunshine_duration_1h:min', 'sun_azimuth:d', 'sun_elevation:d', 'effective_cloud_cover:p', ]]
y_train = train_data['pv_production']

# %%
X_test = test_data[['precip_1h:mm', 'clear_sky_rad:W', 'diffuse_rad:W', 'sunshine_duration_1h:min', 'sun_azimuth:d', 'sun_elevation:d', 'effective_cloud_cover:p', ]]
y_test = test_data['pv_production']

# %% [markdown]
# ### Creating validation splits

# %%
from sklearn.model_selection import train_test_split

# Use the same function above for the validation set
X_train, X_val, y_train, y_val = train_test_split(
    X_train, y_train, test_size = 0.1, random_state = 42  # val = 10%
)

# %% [markdown]
# ## Creating y_train and y_test for solar production

# %%
# creating y_train dataframe
y_train = y.copy()['pv_production']

# Importing y_test
y_test = pd.read_csv('/Users/niki/code/Niki827/watt_squad/raw_data/test.csv')
y_test = y_test['pv_production']

# %% [markdown]
# ## Creating X_val and y_val for solar production

# %%
from sklearn.model_selection import train_test_split

# Use the same function above for the validation set
X_train_transformed, X_val, y_train, y_val = train_test_split(
    X_train_transformed, y_train, test_size = 0.1, random_state = 42  # val = 10%
)

# %% [markdown]
# ## Building an XGBRegressor

# %%
from xgboost import XGBRegressor

xgb_reg = XGBRegressor(max_depth=7, n_estimators=500, learning_rate=0.1)

xgb_history = xgb_reg.fit(X_train_transformed, y_train,
    # evaluate loss at each iteration
    eval_set=[(X_train_transformed, y_train), (X_test_transformed, y_test)],  
)

#y_pred = xgb_reg.predict(X_val)
# Out:
# [0]	validation_0-rmse:14.45653	validation_1-rmse:9.43482
# [1]	validation_0-rmse:13.29310	validation_1-rmse:8.81929
# [2]	validation_0-rmse:12.26901	validation_1-rmse:8.24040
# [3]	validation_0-rmse:11.32636	validation_1-rmse:7.68562
# [4]	validation_0-rmse:10.49294	validation_1-rmse:7.26338
# [5]	validation_0-rmse:9.74128	validation_1-rmse:6.87812
# [6]	validation_0-rmse:9.08592	validation_1-rmse:6.50428
# [7]	validation_0-rmse:8.49929	validation_1-rmse:6.22047
# [8]	validation_0-rmse:7.98058	validation_1-rmse:5.97537
# [9]	validation_0-rmse:7.52255	validation_1-rmse:5.77193
# [10]	validation_0-rmse:7.11024	validation_1-rmse:5.60122
# [11]	validation_0-rmse:6.74633	validation_1-rmse:5.45701
# [12]	validation_0-rmse:6.42234	validation_1-rmse:5.32163
# [13]	validation_0-rmse:6.13558	validation_1-rmse:5.21701
# [14]	validation_0-rmse:5.86995	validation_1-rmse:5.14506
# [15]	validation_0-rmse:5.63193	validation_1-rmse:5.08249
# [16]	validation_0-rmse:5.41336	validation_1-rmse:5.04057
# [17]	validation_0-rmse:5.21133	validation_1-rmse:4.98805
# [18]	validation_0-rmse:5.01052	validation_1-rmse:4.93606
# [19]	validation_0-rmse:4.86050	validation_1-rmse:4.91346
# [20]	validation_0-rmse:4.71702	validation_1-rmse:4.89638
# [21]	validation_0-rmse:4.57666	validation_1-rmse:4.87653
# [22]	validation_0-rmse:4.44853	validation_1-rmse:4.86467
# [23]	validation_0-rmse:4.35480	validation_1-rmse:4.85521
# [24]	validation_0-rmse:4.25677	validation_1-rmse:4.84208
# [25]	validation_0-rmse:4.17369	validation_1-rmse:4.86454
# [26]	validation_0-rmse:4.10630	validation_1-rmse:4.86108
# [27]	validation_0-rmse:4.02051	validation_1-rmse:4.87578
# [28]	validation_0-rmse:3.93228	validation_1-rmse:4.87752
# [29]	validation_0-rmse:3.85557	validation_1-rmse:4.87584
# [30]	validation_0-rmse:3.78209	validation_1-rmse:4.87652
# [31]	validation_0-rmse:3.72076	validation_1-rmse:4.88300
# [32]	validation_0-rmse:3.66154	validation_1-rmse:4.89719
# [33]	validation_0-rmse:3.60140	validation_1-rmse:4.89890
# [34]	validation_0-rmse:3.56382	validation_1-rmse:4.90546
# [35]	validation_0-rmse:3.50078	validation_1-rmse:4.91549
# [36]	validation_0-rmse:3.44841	validation_1-rmse:4.91769
# [37]	validation_0-rmse:3.39906	validation_1-rmse:4.92170
# [38]	validation_0-rmse:3.36260	validation_1-rmse:4.91986
# [39]	validation_0-rmse:3.32961	validation_1-rmse:4.92176
# [40]	validation_0-rmse:3.28859	validation_1-rmse:4.95247
# [41]	validation_0-rmse:3.25620	validation_1-rmse:4.95243
# [42]	validation_0-rmse:3.21945	validation_1-rmse:4.95409
# [43]	validation_0-rmse:3.17805	validation_1-rmse:4.95501
# [44]	validation_0-rmse:3.14941	validation_1-rmse:4.95343
# [45]	validation_0-rmse:3.12182	validation_1-rmse:4.95115
# [46]	validation_0-rmse:3.10122	validation_1-rmse:4.94961
# [47]	validation_0-rmse:3.07535	validation_1-rmse:4.94777
# [48]	validation_0-rmse:3.04048	validation_1-rmse:4.93850
# [49]	validation_0-rmse:3.01441	validation_1-rmse:4.95079
# [50]	validation_0-rmse:2.97688	validation_1-rmse:4.94881
# [51]	validation_0-rmse:2.94631	validation_1-rmse:4.96693
# [52]	validation_0-rmse:2.90505	validation_1-rmse:4.97510
# [53]	validation_0-rmse:2.87472	validation_1-rmse:4.98827
# [54]	validation_0-rmse:2.84914	validation_1-rmse:4.98804
# [55]	validation_0-rmse:2.82740	validation_1-rmse:4.98644
# [56]	validation_0-rmse:2.80391	validation_1-rmse:4.99238
# [57]	validation_0-rmse:2.79196	validation_1-rmse:4.99129
# [58]	validation_0-rmse:2.76822	validation_1-rmse:4.99369
# [59]	validation_0-rmse:2.73596	validation_1-rmse:4.99389
# [60]	validation_0-rmse:2.71540	validation_1-rmse:4.99414
# [61]	validation_0-rmse:2.69397	validation_1-rmse:4.99514
# [62]	validation_0-rmse:2.66127	validation_1-rmse:5.01004
# [63]	validation_0-rmse:2.62726	validation_1-rmse:5.01768
# [64]	validation_0-rmse:2.61131	validation_1-rmse:5.02410
# [65]	validation_0-rmse:2.58608	validation_1-rmse:5.02395
# [66]	validation_0-rmse:2.55632	validation_1-rmse:5.02449
# [67]	validation_0-rmse:2.53065	validation_1-rmse:5.02363
# [68]	validation_0-rmse:2.49257	validation_1-rmse:5.02252
# [69]	validation_0-rmse:2.46291	validation_1-rmse:5.02571
# [70]	validation_0-rmse:2.44827	validation_1-rmse:5.02644
# [71]	validation_0-rmse:2.42199	validation_1-rmse:5.02278
# [72]	validation_0-rmse:2.40556	validation_1-rmse:5.02279
# [73]	validation_0-rmse:2.37575	validation_1-rmse:5.03922
# [74]	validation_0-rmse:2.34539	validation_1-rmse:5.03498
# [75]	validation_0-rmse:2.31952	validation_1-rmse:5.03499
# [76]	validation_0-rmse:2.30534	validation_1-rmse:5.03501
# [77]	validation_0-rmse:2.29426	validation_1-rmse:5.03502
# [78]	validation_0-rmse:2.27149	validation_1-rmse:5.03262
# [79]	validation_0-rmse:2.24417	validation_1-rmse:5.03225
# [80]	validation_0-rmse:2.22346	validation_1-rmse:5.03122
# [81]	validation_0-rmse:2.21805	validation_1-rmse:5.03122
# [82]	validation_0-rmse:2.19357	validation_1-rmse:5.04158
# [83]	validation_0-rmse:2.17055	validation_1-rmse:5.04413
# [84]	validation_0-rmse:2.15480	validation_1-rmse:5.05272
# [85]	validation_0-rmse:2.12725	validation_1-rmse:5.06064
# [86]	validation_0-rmse:2.11481	validation_1-rmse:5.06042
# [87]	validation_0-rmse:2.08980	validation_1-rmse:5.06955
# [88]	validation_0-rmse:2.07273	validation_1-rmse:5.07604
# [89]	validation_0-rmse:2.06181	validation_1-rmse:5.07626
# [90]	validation_0-rmse:2.04679	validation_1-rmse:5.07663
# [91]	validation_0-rmse:2.03244	validation_1-rmse:5.07664
# [92]	validation_0-rmse:2.01831	validation_1-rmse:5.07629
# [93]	validation_0-rmse:2.00136	validation_1-rmse:5.07110
# [94]	validation_0-rmse:1.98977	validation_1-rmse:5.06932
# [95]	validation_0-rmse:1.97534	validation_1-rmse:5.07927
# [96]	validation_0-rmse:1.96535	validation_1-rmse:5.07933
# [97]	validation_0-rmse:1.95638	validation_1-rmse:5.07929
# [98]	validation_0-rmse:1.93651	validation_1-rmse:5.08901
# [99]	validation_0-rmse:1.91385	validation_1-rmse:5.09389
# [100]	validation_0-rmse:1.90491	validation_1-rmse:5.09380
# [101]	validation_0-rmse:1.89037	validation_1-rmse:5.09041
# [102]	validation_0-rmse:1.86742	validation_1-rmse:5.09628
# [103]	validation_0-rmse:1.85124	validation_1-rmse:5.10154
# [104]	validation_0-rmse:1.83204	validation_1-rmse:5.10274
# [105]	validation_0-rmse:1.82430	validation_1-rmse:5.10273
# [106]	validation_0-rmse:1.79815	validation_1-rmse:5.09716
# [107]	validation_0-rmse:1.78008	validation_1-rmse:5.10096
# [108]	validation_0-rmse:1.76406	validation_1-rmse:5.10365
# [109]	validation_0-rmse:1.74833	validation_1-rmse:5.10106
# [110]	validation_0-rmse:1.73225	validation_1-rmse:5.10324
# [111]	validation_0-rmse:1.72327	validation_1-rmse:5.10279
# [112]	validation_0-rmse:1.71003	validation_1-rmse:5.10026
# [113]	validation_0-rmse:1.69114	validation_1-rmse:5.09689
# [114]	validation_0-rmse:1.67725	validation_1-rmse:5.09707
# [115]	validation_0-rmse:1.66878	validation_1-rmse:5.09475
# [116]	validation_0-rmse:1.66019	validation_1-rmse:5.09227
# [117]	validation_0-rmse:1.65613	validation_1-rmse:5.09241
# [118]	validation_0-rmse:1.64727	validation_1-rmse:5.09215
# [119]	validation_0-rmse:1.64035	validation_1-rmse:5.09107
# [120]	validation_0-rmse:1.63147	validation_1-rmse:5.08972
# [121]	validation_0-rmse:1.61569	validation_1-rmse:5.09292
# [122]	validation_0-rmse:1.60178	validation_1-rmse:5.09193
# [123]	validation_0-rmse:1.59257	validation_1-rmse:5.09197
# [124]	validation_0-rmse:1.58744	validation_1-rmse:5.09027
# [125]	validation_0-rmse:1.58141	validation_1-rmse:5.09043
# [126]	validation_0-rmse:1.56504	validation_1-rmse:5.09887
# [127]	validation_0-rmse:1.54867	validation_1-rmse:5.09750
# [128]	validation_0-rmse:1.53222	validation_1-rmse:5.10660
# [129]	validation_0-rmse:1.52205	validation_1-rmse:5.10712
# [130]	validation_0-rmse:1.51549	validation_1-rmse:5.10697
# [131]	validation_0-rmse:1.51053	validation_1-rmse:5.10554
# [132]	validation_0-rmse:1.49872	validation_1-rmse:5.10594
# [133]	validation_0-rmse:1.48770	validation_1-rmse:5.09989
# [134]	validation_0-rmse:1.48000	validation_1-rmse:5.09923
# [135]	validation_0-rmse:1.46110	validation_1-rmse:5.10018
# [136]	validation_0-rmse:1.45498	validation_1-rmse:5.10019
# [137]	validation_0-rmse:1.44314	validation_1-rmse:5.10197
# [138]	validation_0-rmse:1.43073	validation_1-rmse:5.10593
# [139]	validation_0-rmse:1.41989	validation_1-rmse:5.10488
# [140]	validation_0-rmse:1.40339	validation_1-rmse:5.10644
# [141]	validation_0-rmse:1.39968	validation_1-rmse:5.10702
# [142]	validation_0-rmse:1.39042	validation_1-rmse:5.10685
# [143]	validation_0-rmse:1.38257	validation_1-rmse:5.10846
# [144]	validation_0-rmse:1.37651	validation_1-rmse:5.11071
# [145]	validation_0-rmse:1.36267	validation_1-rmse:5.11308
# [146]	validation_0-rmse:1.35342	validation_1-rmse:5.11318
# [147]	validation_0-rmse:1.34108	validation_1-rmse:5.11291
# [148]	validation_0-rmse:1.33069	validation_1-rmse:5.11754
# [149]	validation_0-rmse:1.31671	validation_1-rmse:5.11484
# [150]	validation_0-rmse:1.30917	validation_1-rmse:5.11562
# [151]	validation_0-rmse:1.30532	validation_1-rmse:5.11348
# [152]	validation_0-rmse:1.28728	validation_1-rmse:5.11460
# [153]	validation_0-rmse:1.28066	validation_1-rmse:5.11566
# [154]	validation_0-rmse:1.27753	validation_1-rmse:5.11567
# [155]	validation_0-rmse:1.26969	validation_1-rmse:5.11879
# [156]	validation_0-rmse:1.25944	validation_1-rmse:5.11915
# [157]	validation_0-rmse:1.24436	validation_1-rmse:5.11932
# [158]	validation_0-rmse:1.23907	validation_1-rmse:5.11751
# [159]	validation_0-rmse:1.23364	validation_1-rmse:5.11767
# [160]	validation_0-rmse:1.22262	validation_1-rmse:5.12454
# [161]	validation_0-rmse:1.21914	validation_1-rmse:5.12416
# [162]	validation_0-rmse:1.20987	validation_1-rmse:5.12242
# [163]	validation_0-rmse:1.20569	validation_1-rmse:5.12243
# [164]	validation_0-rmse:1.19851	validation_1-rmse:5.12446
# [165]	validation_0-rmse:1.18217	validation_1-rmse:5.12525
# [166]	validation_0-rmse:1.17404	validation_1-rmse:5.12747
# [167]	validation_0-rmse:1.16577	validation_1-rmse:5.12416
# [168]	validation_0-rmse:1.15676	validation_1-rmse:5.12424
# [169]	validation_0-rmse:1.14863	validation_1-rmse:5.12408
# [170]	validation_0-rmse:1.14553	validation_1-rmse:5.12461
# [171]	validation_0-rmse:1.13057	validation_1-rmse:5.12516
# [172]	validation_0-rmse:1.12651	validation_1-rmse:5.12581
# [173]	validation_0-rmse:1.11937	validation_1-rmse:5.12891
# [174]	validation_0-rmse:1.11671	validation_1-rmse:5.12956
# [175]	validation_0-rmse:1.10495	validation_1-rmse:5.13101
# [176]	validation_0-rmse:1.10117	validation_1-rmse:5.13079
# [177]	validation_0-rmse:1.09030	validation_1-rmse:5.13646
# [178]	validation_0-rmse:1.08373	validation_1-rmse:5.13991
# [179]	validation_0-rmse:1.07487	validation_1-rmse:5.14000
# [180]	validation_0-rmse:1.06568	validation_1-rmse:5.13673
# [181]	validation_0-rmse:1.06098	validation_1-rmse:5.13660
# [182]	validation_0-rmse:1.05569	validation_1-rmse:5.13699
# [183]	validation_0-rmse:1.05166	validation_1-rmse:5.13506
# [184]	validation_0-rmse:1.04866	validation_1-rmse:5.13300
# [185]	validation_0-rmse:1.03624	validation_1-rmse:5.13632
# [186]	validation_0-rmse:1.02987	validation_1-rmse:5.13646
# [187]	validation_0-rmse:1.02567	validation_1-rmse:5.13670
# [188]	validation_0-rmse:1.02036	validation_1-rmse:5.13652
# [189]	validation_0-rmse:1.01578	validation_1-rmse:5.13737
# [190]	validation_0-rmse:1.01236	validation_1-rmse:5.13951
# [191]	validation_0-rmse:1.00752	validation_1-rmse:5.13974
# [192]	validation_0-rmse:1.00072	validation_1-rmse:5.14405
# [193]	validation_0-rmse:0.99004	validation_1-rmse:5.14660
# [194]	validation_0-rmse:0.97992	validation_1-rmse:5.14941
# [195]	validation_0-rmse:0.97222	validation_1-rmse:5.15322
# [196]	validation_0-rmse:0.96825	validation_1-rmse:5.15325
# [197]	validation_0-rmse:0.96424	validation_1-rmse:5.15341
# [198]	validation_0-rmse:0.95503	validation_1-rmse:5.15208
# [199]	validation_0-rmse:0.94616	validation_1-rmse:5.15207
# [200]	validation_0-rmse:0.93478	validation_1-rmse:5.15488
# [201]	validation_0-rmse:0.92562	validation_1-rmse:5.15233
# [202]	validation_0-rmse:0.91937	validation_1-rmse:5.15556
# [203]	validation_0-rmse:0.90935	validation_1-rmse:5.15477
# [204]	validation_0-rmse:0.90361	validation_1-rmse:5.15530
# [205]	validation_0-rmse:0.89664	validation_1-rmse:5.15568
# [206]	validation_0-rmse:0.89036	validation_1-rmse:5.15575
# [207]	validation_0-rmse:0.88571	validation_1-rmse:5.15812
# [208]	validation_0-rmse:0.88284	validation_1-rmse:5.15851
# [209]	validation_0-rmse:0.87947	validation_1-rmse:5.16098
# [210]	validation_0-rmse:0.87550	validation_1-rmse:5.16115
# [211]	validation_0-rmse:0.87155	validation_1-rmse:5.16315
# [212]	validation_0-rmse:0.86503	validation_1-rmse:5.16348
# [213]	validation_0-rmse:0.86184	validation_1-rmse:5.16353
# [214]	validation_0-rmse:0.85560	validation_1-rmse:5.16570
# [215]	validation_0-rmse:0.85201	validation_1-rmse:5.16555
# [216]	validation_0-rmse:0.84808	validation_1-rmse:5.16799
# [217]	validation_0-rmse:0.84258	validation_1-rmse:5.16913
# [218]	validation_0-rmse:0.83642	validation_1-rmse:5.17061
# [219]	validation_0-rmse:0.83421	validation_1-rmse:5.17096
# [220]	validation_0-rmse:0.82969	validation_1-rmse:5.17059
# [221]	validation_0-rmse:0.82716	validation_1-rmse:5.17006
# [222]	validation_0-rmse:0.81787	validation_1-rmse:5.17088
# [223]	validation_0-rmse:0.81471	validation_1-rmse:5.17077
# [224]	validation_0-rmse:0.80787	validation_1-rmse:5.17019
# [225]	validation_0-rmse:0.80573	validation_1-rmse:5.17043
# [226]	validation_0-rmse:0.80008	validation_1-rmse:5.17111
# [227]	validation_0-rmse:0.79628	validation_1-rmse:5.17008
# [228]	validation_0-rmse:0.78614	validation_1-rmse:5.17513
# [229]	validation_0-rmse:0.78540	validation_1-rmse:5.17512
# [230]	validation_0-rmse:0.78012	validation_1-rmse:5.17431
# [231]	validation_0-rmse:0.77608	validation_1-rmse:5.17506
# [232]	validation_0-rmse:0.77375	validation_1-rmse:5.17291
# [233]	validation_0-rmse:0.76310	validation_1-rmse:5.17206
# [234]	validation_0-rmse:0.75084	validation_1-rmse:5.17278
# [235]	validation_0-rmse:0.74829	validation_1-rmse:5.17171
# [236]	validation_0-rmse:0.74681	validation_1-rmse:5.17331
# [237]	validation_0-rmse:0.74265	validation_1-rmse:5.17259
# [238]	validation_0-rmse:0.73942	validation_1-rmse:5.17251
# [239]	validation_0-rmse:0.73870	validation_1-rmse:5.17251
# [240]	validation_0-rmse:0.73665	validation_1-rmse:5.17251
# [241]	validation_0-rmse:0.73057	validation_1-rmse:5.17318
# [242]	validation_0-rmse:0.72548	validation_1-rmse:5.17393
# [243]	validation_0-rmse:0.72049	validation_1-rmse:5.17600
# [244]	validation_0-rmse:0.71586	validation_1-rmse:5.17595
# [245]	validation_0-rmse:0.71458	validation_1-rmse:5.17555
# [246]	validation_0-rmse:0.71150	validation_1-rmse:5.17569
# [247]	validation_0-rmse:0.70882	validation_1-rmse:5.17567
# [248]	validation_0-rmse:0.70715	validation_1-rmse:5.17573
# [249]	validation_0-rmse:0.70319	validation_1-rmse:5.17650
# [250]	validation_0-rmse:0.70008	validation_1-rmse:5.17667
# [251]	validation_0-rmse:0.69561	validation_1-rmse:5.17710
# [252]	validation_0-rmse:0.68770	validation_1-rmse:5.17599
# [253]	validation_0-rmse:0.67764	validation_1-rmse:5.17530
# [254]	validation_0-rmse:0.67519	validation_1-rmse:5.17534
# [255]	validation_0-rmse:0.67205	validation_1-rmse:5.17737
# [256]	validation_0-rmse:0.66799	validation_1-rmse:5.17793
# [257]	validation_0-rmse:0.66143	validation_1-rmse:5.17645
# [258]	validation_0-rmse:0.65941	validation_1-rmse:5.17628
# [259]	validation_0-rmse:0.65247	validation_1-rmse:5.17553
# [260]	validation_0-rmse:0.65030	validation_1-rmse:5.17617
# [261]	validation_0-rmse:0.64587	validation_1-rmse:5.17598
# [262]	validation_0-rmse:0.64141	validation_1-rmse:5.17357
# [263]	validation_0-rmse:0.63714	validation_1-rmse:5.17312
# [264]	validation_0-rmse:0.63553	validation_1-rmse:5.17315
# [265]	validation_0-rmse:0.63079	validation_1-rmse:5.17219
# [266]	validation_0-rmse:0.62763	validation_1-rmse:5.17476
# [267]	validation_0-rmse:0.62488	validation_1-rmse:5.17500
# [268]	validation_0-rmse:0.62037	validation_1-rmse:5.17595
# [269]	validation_0-rmse:0.61143	validation_1-rmse:5.17566
# [270]	validation_0-rmse:0.60925	validation_1-rmse:5.17546
# [271]	validation_0-rmse:0.60603	validation_1-rmse:5.17631
# [272]	validation_0-rmse:0.60258	validation_1-rmse:5.17643
# [273]	validation_0-rmse:0.60025	validation_1-rmse:5.17607
# [274]	validation_0-rmse:0.59807	validation_1-rmse:5.17609
# [275]	validation_0-rmse:0.59187	validation_1-rmse:5.17784
# [276]	validation_0-rmse:0.58688	validation_1-rmse:5.17906
# [277]	validation_0-rmse:0.58535	validation_1-rmse:5.17906
# [278]	validation_0-rmse:0.58102	validation_1-rmse:5.18057
# [279]	validation_0-rmse:0.57848	validation_1-rmse:5.18036
# [280]	validation_0-rmse:0.57099	validation_1-rmse:5.18052
# [281]	validation_0-rmse:0.56833	validation_1-rmse:5.18096
# [282]	validation_0-rmse:0.56505	validation_1-rmse:5.18065
# [283]	validation_0-rmse:0.56208	validation_1-rmse:5.18052
# [284]	validation_0-rmse:0.55596	validation_1-rmse:5.17928
# [285]	validation_0-rmse:0.55089	validation_1-rmse:5.18828
# [286]	validation_0-rmse:0.54936	validation_1-rmse:5.18833
# [287]	validation_0-rmse:0.54589	validation_1-rmse:5.18996
# [288]	validation_0-rmse:0.54265	validation_1-rmse:5.18734
# [289]	validation_0-rmse:0.53764	validation_1-rmse:5.18644
# [290]	validation_0-rmse:0.53429	validation_1-rmse:5.18624
# [291]	validation_0-rmse:0.53154	validation_1-rmse:5.18645
# [292]	validation_0-rmse:0.52927	validation_1-rmse:5.18706
# [293]	validation_0-rmse:0.52706	validation_1-rmse:5.18708
# [294]	validation_0-rmse:0.52619	validation_1-rmse:5.18693
# [295]	validation_0-rmse:0.52528	validation_1-rmse:5.18689
# [296]	validation_0-rmse:0.52405	validation_1-rmse:5.18689
# [297]	validation_0-rmse:0.52136	validation_1-rmse:5.18686
# [298]	validation_0-rmse:0.51820	validation_1-rmse:5.18593
# [299]	validation_0-rmse:0.51703	validation_1-rmse:5.18615
# [300]	validation_0-rmse:0.51576	validation_1-rmse:5.18627
# [301]	validation_0-rmse:0.51241	validation_1-rmse:5.18626
# [302]	validation_0-rmse:0.50976	validation_1-rmse:5.18756
# [303]	validation_0-rmse:0.50908	validation_1-rmse:5.18762
# [304]	validation_0-rmse:0.50313	validation_1-rmse:5.18999
# [305]	validation_0-rmse:0.50268	validation_1-rmse:5.19000
# [306]	validation_0-rmse:0.49984	validation_1-rmse:5.18996
# [307]	validation_0-rmse:0.49653	validation_1-rmse:5.19111
# [308]	validation_0-rmse:0.49159	validation_1-rmse:5.18968
# [309]	validation_0-rmse:0.48685	validation_1-rmse:5.18924
# [310]	validation_0-rmse:0.48581	validation_1-rmse:5.18923
# [311]	validation_0-rmse:0.48248	validation_1-rmse:5.19085
# [312]	validation_0-rmse:0.47994	validation_1-rmse:5.19072
# [313]	validation_0-rmse:0.47475	validation_1-rmse:5.19039
# [314]	validation_0-rmse:0.47215	validation_1-rmse:5.19013
# [315]	validation_0-rmse:0.47068	validation_1-rmse:5.19044
# [316]	validation_0-rmse:0.46793	validation_1-rmse:5.19077
# [317]	validation_0-rmse:0.46611	validation_1-rmse:5.19071
# [318]	validation_0-rmse:0.46382	validation_1-rmse:5.19092
# [319]	validation_0-rmse:0.46262	validation_1-rmse:5.19094
# [320]	validation_0-rmse:0.45903	validation_1-rmse:5.19133
# [321]	validation_0-rmse:0.45610	validation_1-rmse:5.19194
# [322]	validation_0-rmse:0.45132	validation_1-rmse:5.19194
# [323]	validation_0-rmse:0.44639	validation_1-rmse:5.19106
# [324]	validation_0-rmse:0.44362	validation_1-rmse:5.19074
# [325]	validation_0-rmse:0.44101	validation_1-rmse:5.19047
# [326]	validation_0-rmse:0.43866	validation_1-rmse:5.18935
# [327]	validation_0-rmse:0.43455	validation_1-rmse:5.18945
# [328]	validation_0-rmse:0.43332	validation_1-rmse:5.18952
# [329]	validation_0-rmse:0.43107	validation_1-rmse:5.18906
# [330]	validation_0-rmse:0.43081	validation_1-rmse:5.18902
# [331]	validation_0-rmse:0.42934	validation_1-rmse:5.18906
# [332]	validation_0-rmse:0.42667	validation_1-rmse:5.18957
# [333]	validation_0-rmse:0.42627	validation_1-rmse:5.18953
# [334]	validation_0-rmse:0.42458	validation_1-rmse:5.18941
# [335]	validation_0-rmse:0.42334	validation_1-rmse:5.18941
# [336]	validation_0-rmse:0.42153	validation_1-rmse:5.18941
# [337]	validation_0-rmse:0.41809	validation_1-rmse:5.19049
# [338]	validation_0-rmse:0.41498	validation_1-rmse:5.19132
# [339]	validation_0-rmse:0.41430	validation_1-rmse:5.19127
# [340]	validation_0-rmse:0.41104	validation_1-rmse:5.19263
# [341]	validation_0-rmse:0.40959	validation_1-rmse:5.19256
# [342]	validation_0-rmse:0.40585	validation_1-rmse:5.19300
# [343]	validation_0-rmse:0.40322	validation_1-rmse:5.19270
# [344]	validation_0-rmse:0.40014	validation_1-rmse:5.19315
# [345]	validation_0-rmse:0.39823	validation_1-rmse:5.19299
# [346]	validation_0-rmse:0.39680	validation_1-rmse:5.19249
# [347]	validation_0-rmse:0.39454	validation_1-rmse:5.19284
# [348]	validation_0-rmse:0.39261	validation_1-rmse:5.19280
# [349]	validation_0-rmse:0.39060	validation_1-rmse:5.19318
# [350]	validation_0-rmse:0.38764	validation_1-rmse:5.19338
# [351]	validation_0-rmse:0.38576	validation_1-rmse:5.19356
# [352]	validation_0-rmse:0.38336	validation_1-rmse:5.19323
# [353]	validation_0-rmse:0.38282	validation_1-rmse:5.19321
# [354]	validation_0-rmse:0.38096	validation_1-rmse:5.19329
# [355]	validation_0-rmse:0.37784	validation_1-rmse:5.19454
# [356]	validation_0-rmse:0.37587	validation_1-rmse:5.19457
# [357]	validation_0-rmse:0.37542	validation_1-rmse:5.19435
# [358]	validation_0-rmse:0.37423	validation_1-rmse:5.19443
# [359]	validation_0-rmse:0.37301	validation_1-rmse:5.19431
# [360]	validation_0-rmse:0.37027	validation_1-rmse:5.19436
# [361]	validation_0-rmse:0.36652	validation_1-rmse:5.19729
# [362]	validation_0-rmse:0.36302	validation_1-rmse:5.19805
# [363]	validation_0-rmse:0.36192	validation_1-rmse:5.19792
# [364]	validation_0-rmse:0.36066	validation_1-rmse:5.19687
# [365]	validation_0-rmse:0.35809	validation_1-rmse:5.19627
# [366]	validation_0-rmse:0.35482	validation_1-rmse:5.19712
# [367]	validation_0-rmse:0.35396	validation_1-rmse:5.19628
# [368]	validation_0-rmse:0.35073	validation_1-rmse:5.19821
# [369]	validation_0-rmse:0.34844	validation_1-rmse:5.19829
# [370]	validation_0-rmse:0.34639	validation_1-rmse:5.19807
# [371]	validation_0-rmse:0.34488	validation_1-rmse:5.19760
# [372]	validation_0-rmse:0.34158	validation_1-rmse:5.19613
# [373]	validation_0-rmse:0.33879	validation_1-rmse:5.19521
# [374]	validation_0-rmse:0.33732	validation_1-rmse:5.19510
# [375]	validation_0-rmse:0.33584	validation_1-rmse:5.19517
# [376]	validation_0-rmse:0.33319	validation_1-rmse:5.19514
# [377]	validation_0-rmse:0.33271	validation_1-rmse:5.19514
# [378]	validation_0-rmse:0.33168	validation_1-rmse:5.19515
# [379]	validation_0-rmse:0.33113	validation_1-rmse:5.19518
# [380]	validation_0-rmse:0.32872	validation_1-rmse:5.19518
# [381]	validation_0-rmse:0.32645	validation_1-rmse:5.19557
# [382]	validation_0-rmse:0.32591	validation_1-rmse:5.19558
# [383]	validation_0-rmse:0.32538	validation_1-rmse:5.19558
# [384]	validation_0-rmse:0.32500	validation_1-rmse:5.19573
# [385]	validation_0-rmse:0.32394	validation_1-rmse:5.19600
# [386]	validation_0-rmse:0.32251	validation_1-rmse:5.19603
# [387]	validation_0-rmse:0.32158	validation_1-rmse:5.19630
# [388]	validation_0-rmse:0.32029	validation_1-rmse:5.19579
# [389]	validation_0-rmse:0.31739	validation_1-rmse:5.19608
# [390]	validation_0-rmse:0.31460	validation_1-rmse:5.19589
# [391]	validation_0-rmse:0.31402	validation_1-rmse:5.19593
# [392]	validation_0-rmse:0.31273	validation_1-rmse:5.19544
# [393]	validation_0-rmse:0.31035	validation_1-rmse:5.19580
# [394]	validation_0-rmse:0.30929	validation_1-rmse:5.19599
# [395]	validation_0-rmse:0.30781	validation_1-rmse:5.19576
# [396]	validation_0-rmse:0.30500	validation_1-rmse:5.19418
# [397]	validation_0-rmse:0.30349	validation_1-rmse:5.19432
# [398]	validation_0-rmse:0.30178	validation_1-rmse:5.19439
# [399]	validation_0-rmse:0.30042	validation_1-rmse:5.19456
# [400]	validation_0-rmse:0.29941	validation_1-rmse:5.19456
# [401]	validation_0-rmse:0.29694	validation_1-rmse:5.19383
# [402]	validation_0-rmse:0.29566	validation_1-rmse:5.19383
# [403]	validation_0-rmse:0.29383	validation_1-rmse:5.19371
# [404]	validation_0-rmse:0.29238	validation_1-rmse:5.19367
# [405]	validation_0-rmse:0.29053	validation_1-rmse:5.19377
# [406]	validation_0-rmse:0.28986	validation_1-rmse:5.19398
# [407]	validation_0-rmse:0.28853	validation_1-rmse:5.19392
# [408]	validation_0-rmse:0.28578	validation_1-rmse:5.19396
# [409]	validation_0-rmse:0.28460	validation_1-rmse:5.19417
# [410]	validation_0-rmse:0.28364	validation_1-rmse:5.19412
# [411]	validation_0-rmse:0.28251	validation_1-rmse:5.19337
# [412]	validation_0-rmse:0.27953	validation_1-rmse:5.19378
# [413]	validation_0-rmse:0.27682	validation_1-rmse:5.19383
# [414]	validation_0-rmse:0.27496	validation_1-rmse:5.19385
# [415]	validation_0-rmse:0.27427	validation_1-rmse:5.19405
# [416]	validation_0-rmse:0.27033	validation_1-rmse:5.19465
# [417]	validation_0-rmse:0.26751	validation_1-rmse:5.19463
# [418]	validation_0-rmse:0.26644	validation_1-rmse:5.19445
# [419]	validation_0-rmse:0.26592	validation_1-rmse:5.19445
# [420]	validation_0-rmse:0.26343	validation_1-rmse:5.19487
# [421]	validation_0-rmse:0.26245	validation_1-rmse:5.19485
# [422]	validation_0-rmse:0.26210	validation_1-rmse:5.19485
# [423]	validation_0-rmse:0.26065	validation_1-rmse:5.19509
# [424]	validation_0-rmse:0.26025	validation_1-rmse:5.19523
# [425]	validation_0-rmse:0.25884	validation_1-rmse:5.19553
# [426]	validation_0-rmse:0.25828	validation_1-rmse:5.19553
# [427]	validation_0-rmse:0.25712	validation_1-rmse:5.19583
# [428]	validation_0-rmse:0.25577	validation_1-rmse:5.19591
# [429]	validation_0-rmse:0.25386	validation_1-rmse:5.19559
# [430]	validation_0-rmse:0.25238	validation_1-rmse:5.19558
# [431]	validation_0-rmse:0.25135	validation_1-rmse:5.19547
# [432]	validation_0-rmse:0.25045	validation_1-rmse:5.19549
# [433]	validation_0-rmse:0.24968	validation_1-rmse:5.19546
# [434]	validation_0-rmse:0.24768	validation_1-rmse:5.19556
# [435]	validation_0-rmse:0.24696	validation_1-rmse:5.19520
# [436]	validation_0-rmse:0.24643	validation_1-rmse:5.19520
# [437]	validation_0-rmse:0.24414	validation_1-rmse:5.19628
# [438]	validation_0-rmse:0.24305	validation_1-rmse:5.19613
# [439]	validation_0-rmse:0.24071	validation_1-rmse:5.19678
# [440]	validation_0-rmse:0.23959	validation_1-rmse:5.19688
# [441]	validation_0-rmse:0.23795	validation_1-rmse:5.19678
# [442]	validation_0-rmse:0.23583	validation_1-rmse:5.19656
# [443]	validation_0-rmse:0.23440	validation_1-rmse:5.19586
# [444]	validation_0-rmse:0.23307	validation_1-rmse:5.19659
# [445]	validation_0-rmse:0.23219	validation_1-rmse:5.19634
# [446]	validation_0-rmse:0.23110	validation_1-rmse:5.19633
# [447]	validation_0-rmse:0.22990	validation_1-rmse:5.19614
# [448]	validation_0-rmse:0.22755	validation_1-rmse:5.19582
# [449]	validation_0-rmse:0.22607	validation_1-rmse:5.19727
# [450]	validation_0-rmse:0.22485	validation_1-rmse:5.19711
# [451]	validation_0-rmse:0.22295	validation_1-rmse:5.19744
# [452]	validation_0-rmse:0.22221	validation_1-rmse:5.19797
# [453]	validation_0-rmse:0.22016	validation_1-rmse:5.19785
# [454]	validation_0-rmse:0.21874	validation_1-rmse:5.19765
# [455]	validation_0-rmse:0.21857	validation_1-rmse:5.19769
# [456]	validation_0-rmse:0.21672	validation_1-rmse:5.19711
# [457]	validation_0-rmse:0.21512	validation_1-rmse:5.19781
# [458]	validation_0-rmse:0.21480	validation_1-rmse:5.19768
# [459]	validation_0-rmse:0.21355	validation_1-rmse:5.19740
# [460]	validation_0-rmse:0.21257	validation_1-rmse:5.19727
# [461]	validation_0-rmse:0.21082	validation_1-rmse:5.19776
# [462]	validation_0-rmse:0.21010	validation_1-rmse:5.19776
# [463]	validation_0-rmse:0.20924	validation_1-rmse:5.19818
# [464]	validation_0-rmse:0.20797	validation_1-rmse:5.19818
# [465]	validation_0-rmse:0.20638	validation_1-rmse:5.19706
# [466]	validation_0-rmse:0.20564	validation_1-rmse:5.19687
# [467]	validation_0-rmse:0.20454	validation_1-rmse:5.19780
# [468]	validation_0-rmse:0.20381	validation_1-rmse:5.19786
# [469]	validation_0-rmse:0.20230	validation_1-rmse:5.19782
# [470]	validation_0-rmse:0.20197	validation_1-rmse:5.19772
# [471]	validation_0-rmse:0.20106	validation_1-rmse:5.19740
# [472]	validation_0-rmse:0.19998	validation_1-rmse:5.19760
# [473]	validation_0-rmse:0.19903	validation_1-rmse:5.19750
# [474]	validation_0-rmse:0.19764	validation_1-rmse:5.19725
# [475]	validation_0-rmse:0.19659	validation_1-rmse:5.19700
# [476]	validation_0-rmse:0.19576	validation_1-rmse:5.19764
# [477]	validation_0-rmse:0.19494	validation_1-rmse:5.19753
# [478]	validation_0-rmse:0.19393	validation_1-rmse:5.19745
# [479]	validation_0-rmse:0.19289	validation_1-rmse:5.19763
# [480]	validation_0-rmse:0.19191	validation_1-rmse:5.19784
# [481]	validation_0-rmse:0.19112	validation_1-rmse:5.19767
# [482]	validation_0-rmse:0.19085	validation_1-rmse:5.19756
# [483]	validation_0-rmse:0.19023	validation_1-rmse:5.19785
# [484]	validation_0-rmse:0.18952	validation_1-rmse:5.19766
# [485]	validation_0-rmse:0.18838	validation_1-rmse:5.19791
# [486]	validation_0-rmse:0.18728	validation_1-rmse:5.19760
# [487]	validation_0-rmse:0.18604	validation_1-rmse:5.19756
# [488]	validation_0-rmse:0.18565	validation_1-rmse:5.19756
# [489]	validation_0-rmse:0.18488	validation_1-rmse:5.19761
# [490]	validation_0-rmse:0.18403	validation_1-rmse:5.19754
# [491]	validation_0-rmse:0.18276	validation_1-rmse:5.19706
# [492]	validation_0-rmse:0.18213	validation_1-rmse:5.19717
# [493]	validation_0-rmse:0.18187	validation_1-rmse:5.19721
# [494]	validation_0-rmse:0.18004	validation_1-rmse:5.19714
# [495]	validation_0-rmse:0.17912	validation_1-rmse:5.19721
# [496]	validation_0-rmse:0.17882	validation_1-rmse:5.19724
# [497]	validation_0-rmse:0.17859	validation_1-rmse:5.19731
# [498]	validation_0-rmse:0.17787	validation_1-rmse:5.19727
# [499]	validation_0-rmse:0.17679	validation_1-rmse:5.19692

# %%
print(y_train.mean(), y_train.std())
# Out:
# 7.732718920390049 15.760882726051298

# %% [markdown]
# # Coding RNNs with Elaine

# %%
X_train_transformed.shape
# Out:
# (9515, 53)

# %%
X_train_tra
# Out:
#       precip_1h:mm  precip_type:idx  prob_precip_1h:p  clear_sky_rad:W  \
# 0       -11.512925              0.0           0.00001         2.302586
# 1       -11.512925              0.0           0.00001       -11.512925
# 2       -11.512925              0.0           0.00001       -11.512925
# 3       -11.512925              0.0           0.00001       -11.512925
# 4       -11.512925              0.0           0.00001       -11.512925
# ...            ...              ...               ...              ...
# 9510    -11.512925              0.0           0.00001       -11.512925
# 9511    -11.512925              0.0           0.00001       -11.512925
# 9512    -11.512925              0.0           0.00001       -11.512925
# 9513    -11.512925              0.0           0.00001       -11.512925
# 9514    -11.512925              0.0           0.00001       -11.512925
#
#       clear_sky_energy_1h:J  diffuse_rad:W  diffuse_rad_1h:Wh  direct_rad:W  \
# 0                 11.079462       2.001481           2.564258     -1.203939
# 1                  9.100648     -11.512925           1.306983    -11.512925
# 2                -11.512925     -11.512925         -11.512925    -11.512925
# 3                -11.512925     -11.512925         -11.512925    -11.512925
# 4                -11.512925     -11.512925         -11.512925    -11.512925
# ...                     ...            ...                ...           ...
# 9510             -11.512925     -11.512925         -11.512925    -11.512925
# 9511             -11.512925     -11.512925         -11.512925    -11.512925
# 9512             -11.512925     -11.512925         -11.512925    -11.512925
# 9513             -11.512925     -11.512925         -11.512925    -11.512925
# 9514             -11.512925     -11.512925         -11.512925    -11.512925
#
#       direct_rad_1h:Wh  global_rad:W  ...  sin_sun_azimuth:d  \
# 0             0.635523      2.041222  ...           0.882291
# 1            -2.024878    -11.512925  ...           0.288029
# 2           -11.512925    -11.512925  ...          -0.575005
# 3           -11.512925    -11.512925  ...           0.134678
# 4           -11.512925    -11.512925  ...           0.478998
# ...                ...           ...  ...                ...
# 9510        -11.512925    -11.512925  ...          -0.963724
# 9511        -11.512925    -11.512925  ...           0.656586
# 9512        -11.512925    -11.512925  ...           0.756310
# 9513        -11.512925    -11.512925  ...           0.012566
# 9514        -11.512925    -11.512925  ...          -0.673013
#
#       cos_sun_azimuth:d  sin_wind_dir_2m:d  cos_wind_dir_2m:d  \
# 0             -0.922834      -9.510565e-01          -0.416281
# 1             -0.808062       9.510565e-01          -0.302370
# 2             -0.653487       8.090170e-01          -0.270600
# 3             -0.468809       2.057035e-14          -0.258819
# 4             -0.261499      -9.510565e-01          -0.351842
# ...                 ...                ...                ...
# 9510           0.200839      -9.510565e-01          -0.699663
# 9511           0.441944      -8.090170e-01          -0.773840
# 9512           0.672664       8.090170e-01          -0.780430
# 9513           0.866060       5.877853e-01          -0.806960
# 9514           0.982402      -3.090170e-01          -0.848972
#
#       sin_wind_dir_10m:d  cos_wind_dir_10m:d  sin_wind_dir_50m:d  \
# 0          -9.510565e-01           -0.416281            0.809017
# 1           9.510565e-01           -0.302370            0.809017
# 2           8.090170e-01           -0.270600            0.309017
# 3           2.057035e-14           -0.258819            0.951057
# 4          -9.510565e-01           -0.351842           -1.000000
# ...                  ...                 ...                 ...
# 9510       -9.510565e-01           -0.699663           -0.587785
# 9511       -8.090170e-01           -0.773840            0.309017
# 9512        8.090170e-01           -0.780430            1.000000
# 9513        5.877853e-01           -0.806960            0.587785
# 9514       -3.090170e-01           -0.848972            0.809017
#
#       cos_wind_dir_50m:d  sin_wind_dir_100m:d  cos_wind_dir_100m:d
# 0              -0.401948            -0.809017            -0.385906
# 1              -0.304033             0.309017            -0.307357
# 2              -0.273959            -0.587785            -0.278991
# 3              -0.265556             0.587785            -0.272280
# 4              -0.350207            -0.809017            -0.346936
# ...                  ...                  ...                  ...
# 9510           -0.626604             0.809017            -0.525472
# 9511           -0.708340            -0.587785            -0.618408
# 9512           -0.713250            -0.809017            -0.619779
# 9513           -0.733730            -0.309017            -0.627963
# 9514           -0.780430            -0.587785            -0.679441
#
# [9515 rows x 50 columns]

# %%
X_train_transformed_new = np.expand_dims(X_train_transformed, axis=0)

# %%
X_train_transformed_new.shape
# Out:
# (1, 9515, 53)

# %%
y.shape
# Out:
# (9515, 3)

# %%
y_new = np.expand_dims(y, axis=0)

# %%
y_new.shape
# Out:
# (1, 9515, 3)

# %%
# 0- Imports
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers

# 1- RNN Architecture
model = Sequential()
model.add(layers.SimpleRNN(units=10, activation='tanh', input_shape=(9515,53)))
model.add(layers.Dense(3, activation="linear"))

# 2- Compilation
model.compile(loss='mse', 
              optimizer=Adam(lr=0.5), metrics=['mae']) # very high lr so we can converge with such a small dataset

# 3- Fit
model.fit(X_train_transformed_new, y_new, epochs=50, verbose=1, batch_size=1)
# Out:
# Epoch 1/50
# 1/1 [==============================] - 1s 533ms/step - loss: 932.5385 - mae: 17.2769
# Epoch 2/50
# 1/1 [==============================] - 0s 216ms/step - loss: 865.0735 - mae: 16.6691
# Epoch 3/50
# 1/1 [==============================] - 0s 217ms/step - loss: 757.4712 - mae: 15.0676
# Epoch 4/50
# 1/1 [==============================] - 0s 220ms/step - loss: 684.7925 - mae: 14.5591
# Epoch 5/50
# 1/1 [==============================] - 0s 215ms/step - loss: 633.2362 - mae: 14.3147
# Epoch 6/50
# 1/1 [==============================] - 0s 225ms/step - loss: 607.2266 - mae: 14.5244
# Epoch 7/50
# 1/1 [==============================] - 0s 209ms/step - loss: 601.2207 - mae: 15.1668
# Epoch 8/50
# 1/1 [==============================] - 0s 212ms/step - loss: 607.4212 - mae: 15.9952
# Epoch 9/50
# 1/1 [==============================] - 0s 211ms/step - loss: 619.1291 - mae: 16.7247
# Epoch 10/50
# 1/1 [==============================] - 0s 211ms/step - loss: 630.7957 - mae: 17.1694
# Epoch 11/50
# 1/1 [==============================] - 0s 219ms/step - loss: 638.5844 - mae: 17.2704
# Epoch 12/50
# 1/1 [==============================] - 0s 214ms/step - loss: 640.8298 - mae: 17.0568
# Epoch 13/50
# 1/1 [==============================] - 0s 214ms/step - loss: 637.5570 - mae: 16.6150
# Epoch 14/50
# 1/1 [==============================] - 0s 216ms/step - loss: 629.7535 - mae: 16.0395
# Epoch 15/50
# 1/1 [==============================] - 0s 213ms/step - loss: 619.1109 - mae: 15.4163
# Epoch 16/50
# 1/1 [==============================] - 0s 209ms/step - loss: 607.9434 - mae: 14.8238
# Epoch 17/50
# 1/1 [==============================] - 0s 215ms/step - loss: 598.7352 - mae: 14.3406
# Epoch 18/50
# 1/1 [==============================] - 0s 215ms/step - loss: 593.3952 - mae: 14.0224
# Epoch 19/50
# 1/1 [==============================] - 0s 238ms/step - loss: 592.6287 - mae: 13.8926
# Epoch 20/50
# 1/1 [==============================] - 0s 227ms/step - loss: 595.7134 - mae: 13.9182
# Epoch 21/50
# 1/1 [==============================] - 0s 216ms/step - loss: 600.7842 - mae: 14.0315
# Epoch 22/50
# 1/1 [==============================] - 0s 213ms/step - loss: 605.5610 - mae: 14.1498
# Epoch 23/50
# 1/1 [==============================] - 0s 218ms/step - loss: 608.2234 - mae: 14.2115
# Epoch 24/50
# 1/1 [==============================] - 0s 213ms/step - loss: 608.0142 - mae: 14.1917
# Epoch 25/50
# 1/1 [==============================] - 0s 213ms/step - loss: 605.3188 - mae: 14.1011
# Epoch 26/50
# 1/1 [==============================] - 0s 212ms/step - loss: 601.2897 - mae: 13.9760
# Epoch 27/50
# 1/1 [==============================] - 0s 214ms/step - loss: 597.2745 - mae: 13.8639
# Epoch 28/50
# 1/1 [==============================] - 0s 210ms/step - loss: 594.3090 - mae: 13.8125
# Epoch 29/50
# 1/1 [==============================] - 0s 210ms/step - loss: 592.8470 - mae: 13.8466
# Epoch 30/50
# 1/1 [==============================] - 0s 213ms/step - loss: 592.7755 - mae: 13.9675
# Epoch 31/50
# 1/1 [==============================] - 0s 210ms/step - loss: 593.6276 - mae: 14.1561
# Epoch 32/50
# 1/1 [==============================] - 0s 211ms/step - loss: 594.8414 - mae: 14.3788
# Epoch 33/50
# 1/1 [==============================] - 0s 216ms/step - loss: 595.9417 - mae: 14.5983
# Epoch 34/50
# 1/1 [==============================] - 0s 222ms/step - loss: 596.6145 - mae: 14.7795
# Epoch 35/50
# 1/1 [==============================] - 0s 221ms/step - loss: 596.7089 - mae: 14.8950
# Epoch 36/50
# 1/1 [==============================] - 0s 211ms/step - loss: 596.2131 - mae: 14.9295
# Epoch 37/50
# 1/1 [==============================] - 0s 219ms/step - loss: 595.2440 - mae: 14.8801
# Epoch 38/50
# 1/1 [==============================] - 0s 215ms/step - loss: 594.0396 - mae: 14.7571
# Epoch 39/50
# 1/1 [==============================] - 0s 212ms/step - loss: 592.9184 - mae: 14.5823
# Epoch 40/50
# 1/1 [==============================] - 0s 217ms/step - loss: 592.1851 - mae: 14.3830
# Epoch 41/50
# 1/1 [==============================] - 0s 211ms/step - loss: 592.0112 - mae: 14.1868
# Epoch 42/50
# 1/1 [==============================] - 0s 210ms/step - loss: 592.3562 - mae: 14.0169
# Epoch 43/50
# 1/1 [==============================] - 0s 213ms/step - loss: 592.9814 - mae: 13.8892
# Epoch 44/50
# 1/1 [==============================] - 0s 217ms/step - loss: 593.5584 - mae: 13.8112
# Epoch 45/50
# 1/1 [==============================] - 0s 215ms/step - loss: 593.8210 - mae: 13.7852
# Epoch 46/50
# 1/1 [==============================] - 0s 213ms/step - loss: 593.6761 - mae: 13.8079
# Epoch 47/50
# 1/1 [==============================] - 0s 215ms/step - loss: 593.2216 - mae: 13.8728
# Epoch 48/50
# 1/1 [==============================] - 0s 217ms/step - loss: 592.6688 - mae: 13.9700
# Epoch 49/50
# 1/1 [==============================] - 0s 214ms/step - loss: 592.2264 - mae: 14.0856
# Epoch 50/50
# 1/1 [==============================] - 0s 215ms/step - loss: 592.0103 - mae: 14.2043

# %%
X_test_transformed_new = np.expand_dims(X_test_transformed, axis=0)

# %%
X_test_transformed_new.shape
# Out:
# (1, 841, 53)

# %%
# 4- Predict
model.predict(X_test_transformed_new)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 2
#       1 # 4- Predict
# ----> 2 model.predict(X_test_transformed_new)
#
# File ~/.pyenv/versions/3.10.6/envs/watt_squad/lib/python3.10/site-packages/keras/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File /var/folders/gq/yvbczhns39z5_88fyxvxmxy00000gn/T/__autograph_generated_filepm65e3kp.py:15, in outer_factory.<locals>.inner_factory.<locals>.tf__predict_function(iterator)
#      13 try:
#      14     do_return = True
# ---> 15     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16 except:
#      17     do_return = False
#
# ValueError: in user code:
#
#     File "/Users/niki/.pyenv/versions/3.10.6/envs/watt_squad/lib/python3.10/site-packages/keras/engine/training.py", line 2041, in predict_function  *
#         return step_function(self, iterator)
#     File "/Users/niki/.pyenv/versions/3.10.6/envs/watt_squad/lib/python3.10/site-packages/keras/engine/training.py", line 2027, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/Users/niki/.pyenv/versions/3.10.6/envs/watt_squad/lib/python3.10/site-packages/keras/engine/training.py", line 2015, in run_step  **
#         outputs = model.predict_step(data)
#     File "/Users/niki/.pyenv/versions/3.10.6/envs/watt_squad/lib/python3.10/site-packages/keras/engine/training.py", line 1983, in predict_step
#         return self(x, training=False)
#     File "/Users/niki/.pyenv/versions/3.10.6/envs/watt_squad/lib/python3.10/site-packages/keras/utils/traceback_utils.py", line 70, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "/Users/niki/.pyenv/versions/3.10.6/envs/watt_squad/lib/python3.10/site-packages/keras/engine/input_spec.py", line 295, in assert_input_compatibility
#         raise ValueError(
#
#     ValueError: Input 0 of layer "sequential_8" is incompatible with the layer: expected shape=(None, 9515, 53), found shape=(None, 841, 53)

# %% [markdown]
# ## To replace and double check

# %% [markdown]
# "input_shape=(9515,3)"
# - replace the 3 with the number of features that we are using

# %% [markdown]
# "model.fit(X, y, epochs=10000, verbose=0)"
# - check that X contains all of our features and y contains all of our targets only
