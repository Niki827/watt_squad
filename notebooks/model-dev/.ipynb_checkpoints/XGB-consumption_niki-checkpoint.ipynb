# %% [markdown]
# # Using XGBoosting with Preprocessed Features

# %%
train = pd.read_csv('/Users/niki/code/Niki827/watt_squad/raw_data/train.csv')
test = pd.read_csv('/Users/niki/code/Niki827/watt_squad/raw_data/test.csv')

# %%
train['pv_production'].sum() + train['wind_production'].sum() - train['consumption'].sum()
# Out:
# 82272.42640168697

# %%
test['pv_production'].sum() + test['wind_production'].sum() - test['consumption'].sum()
# Out:
# -16558.304438724997

# %% [markdown]
# ## Importing data and creating train, val, test splits

# %% [markdown]
# ### Importing preprocessed data

# %%
import pandas as pd
import numpy as np

from sklearn.pipeline import make_pipeline
from sklearn.pipeline import make_union
from sklearn.compose import make_column_transformer

from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import MinMaxScaler

#Reading Raw X_train
X_train = pd.read_csv('/Users/niki/code/Niki827/watt_squad/raw_data/train.csv')
X_test = pd.read_csv('/Users/niki/code/Niki827/watt_squad/raw_data/test.csv')

#Log columns
f_logs = [
    'precip_1h:mm',
    'prob_precip_1h:p',
    'clear_sky_rad:W',
    'clear_sky_energy_1h:J',
    'diffuse_rad:W',
    'diffuse_rad_1h:Wh',
    'direct_rad:W',
    'direct_rad_1h:Wh',
    'global_rad:W',
    'global_rad_1h:Wh',
    'wind_speed_2m:ms',
    'wind_speed_10m:ms',
    'wind_speed_50m:ms',
    'wind_speed_100m:ms'
]

epsilon = 1e-5

for f in f_logs:
    X_train[f] = np.log(X_train[f] + epsilon)
    X_test[f] = np.log(X_test[f] + epsilon)

# Converting time to datetime
# We might have done that before already
X_train['time']= pd.to_datetime(X_train['time'])
X_test['time']= pd.to_datetime(X_test['time'])

#the following two steps creates new columns to get the input for the sine & cosine columns
#creating columns indicating the hour and the month
X_train['hour'] = X_train['time'].dt.hour
X_train['month'] = X_train['time'].dt.month

X_test['hour'] = X_test['time'].dt.hour
X_test['month'] = X_test['time'].dt.month

#creating column indicating the season
def assign_season(month):
    if month in [3, 4, 5]:
        return 1  # Spring
    elif month in [6, 7, 8]:
        return 2  # Summer
    elif month in [9, 10, 11]:
        return 3  # Fall
    else:  # December, January, February
        return 4  # Winter

# X_train
X_train['season'] = X_train['month'].apply(assign_season)

X_train['hour_sine'] = np.sin(2 * np.pi * X_train['hour'] / 24)
X_train['hour_cosine'] = np.cos(2 * np.pi * X_train['hour'] / 24)

X_train['month_sine'] = np.sin(2 * np.pi * X_train['month'] / 12)
X_train['month_cosine'] = np.cos(2 * np.pi * X_train['month'] / 12)

X_train['season_sine'] = np.sin(2 * np.pi * X_train['season'] / 4)
X_train['season_cosine'] = np.cos(2 * np.pi * X_train['season'] / 4)

X_train = X_train.drop(columns = ['hour', 'month', 'season'])

# X_test
X_test['season'] = X_test['month'].apply(assign_season)

X_test['hour_sine'] = np.sin(2 * np.pi * X_test['hour'] / 24)
X_test['hour_cosine'] = np.cos(2 * np.pi * X_test['hour'] / 24)

X_test['month_sine'] = np.sin(2 * np.pi * X_test['month'] / 12)
X_test['month_cosine'] = np.cos(2 * np.pi * X_test['month'] / 12)

X_test['season_sine'] = np.sin(2 * np.pi * X_test['season'] / 4)
X_test['season_cosine'] = np.cos(2 * np.pi * X_test['season'] / 4)

X_test = X_test.drop(columns = ['hour', 'month', 'season'])

# Cyclic features
cyclical_features = ['sun_azimuth:d', 'wind_dir_2m:d', 'wind_dir_10m:d', 'wind_dir_50m:d', 'wind_dir_100m:d']
degrees = 360

for cyclical_feature in cyclical_features:
    sin_column_name = f'sin_{cyclical_feature}'
    cos_column_name = f'cos_{cyclical_feature}'
    X_train[sin_column_name] = np.sin(2 * np.pi * X_train[cyclical_feature]/2)
    X_train[cos_column_name] = np.cos(2 * np.pi * X_train[cyclical_feature]/degrees)
    X_test[sin_column_name] = np.sin(2 * np.pi * X_test[cyclical_feature]/2)
    X_test[cos_column_name] = np.cos(2 * np.pi * X_test[cyclical_feature]/degrees)

X_train = X_train.drop(columns=cyclical_features)
X_test = X_test.drop(columns=cyclical_features)

# targets = ['pv_production', 'wind_production', 'consumption']
f_minmax = [
    'hour_sine',
    'hour_cosine',
    'month_sine',
    'month_cosine',
    'season_sine',
    'season_cosine',
    'precip_1h:mm',
    'prob_precip_1h:p',
    'clear_sky_rad:W',
    'clear_sky_energy_1h:J',
    'diffuse_rad:W',
    'diffuse_rad_1h:Wh',
    'direct_rad:W',
    'direct_rad_1h:Wh',
    'global_rad:W',
    'global_rad_1h:Wh',
    'sunshine_duration_1h:min',
    'low_cloud_cover:p',
    'medium_cloud_cover:p',
    'high_cloud_cover:p',
    'total_cloud_cover:p',
    'effective_cloud_cover:p',
    'sin_sun_azimuth:d',
    'cos_sun_azimuth:d',
    'sin_wind_dir_2m:d',
    'cos_wind_dir_2m:d',
    'sin_wind_dir_10m:d',
    'cos_wind_dir_10m:d',
    'sin_wind_dir_50m:d',
    'cos_wind_dir_50m:d',
    'sin_wind_dir_100m:d',
    'cos_wind_dir_100m:d',
    'relative_humidity_2m:p',
    'relative_humidity_10m:p',
    'relative_humidity_50m:p',
    'relative_humidity_100m:p',
    'dew_point_2m:C',
    'dew_point_10m:C',
    'dew_point_50m:C',
    'dew_point_100m:C',
    'temp'
]
f_standard = ['sun_elevation:d']
f_robust = [
    't_10m:C',
    't_50m:C',
    't_100m:C',
    'wind_speed_2m:ms',
    'wind_speed_10m:ms',
    'wind_speed_50m:ms',
    'wind_speed_100m:ms'
]

f_ohe = ['precip_type:idx']

# other = ['spot_market_price']

# target
y = X_train[['pv_production', 'wind_production', 'consumption']]
# features
X_train = X_train.drop(columns=['time', 'pv_production', 'wind_production', 'consumption', 'spot_market_price'])
X_test = X_test.drop(columns=['time', 'pv_production', 'wind_production', 'consumption', 'spot_market_price'])

# Preprocessing Pipeline
minmax_scaler = MinMaxScaler()
standard_scaler = StandardScaler()
cat_transformer = OneHotEncoder()
robust_scaler = RobustScaler()

preproc_basic = make_column_transformer(
    (minmax_scaler, f_minmax ),
    (standard_scaler, f_standard),
    (robust_scaler, f_robust),
    (cat_transformer, f_ohe),
    remainder='passthrough'
)
# Train X
X_train_transformed = preproc_basic.fit_transform(X_train)

# Adding Column names
X_train_transformed = pd.DataFrame(
    X_train_transformed,
    columns=preproc_basic.get_feature_names_out()
)
# Test x
X_test_transformed = preproc_basic.transform(X_test)
# Adding Column names
X_test_transformed = pd.DataFrame(
    X_test_transformed,
    columns=preproc_basic.get_feature_names_out()
)

# %% [markdown]
# ### Creating y_train and y_test for solar production

# %%
# creating y_train dataframe
y_train = y.copy()['consumption']

# Importing y_test
y_test = pd.read_csv('/Users/niki/code/Niki827/watt_squad/raw_data/test.csv')
y_test = y_test['consumption']

# %% [markdown]
# ### Creating X_val and y_val for solar production

# %%
from sklearn.model_selection import train_test_split

# Use the same function above for the validation set
X_train_transformed, X_val, y_train, y_val = train_test_split(
    X_train_transformed, y_train, test_size = 0.1, random_state = 42  # val = 10%
)

# %% [markdown]
# ## Building an XGB Regressor

# %%
# install Le Wagon Version of XGBoost
#pip install xgboost==1.6.2

# %% [markdown]
# ### Building a first version of the model

# %%
from xgboost import XGBRegressor

xgb_reg = XGBRegressor(max_depth=10, n_estimators=100, learning_rate = 0.1)
xgb_reg.fit(X_train_transformed, y_train,
           # evaluate the loss at each iteration
            eval_set = [(X_train_transformed, y_train), (X_val, y_val)],
            # stop iterating when eval loss increases 5 times in a row
            early_stopping_rounds = 5
           )

y_pred = xgb_reg.predict(X_test_transformed)
# Out:
# /Users/niki/.pyenv/versions/3.10.6/envs/watt_squad/lib/python3.10/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [0]	validation_0-rmse:19.36849	validation_1-rmse:20.08043
# [1]	validation_0-rmse:17.57344	validation_1-rmse:18.33388
# [2]	validation_0-rmse:15.95956	validation_1-rmse:16.79504
# [3]	validation_0-rmse:14.51274	validation_1-rmse:15.42254
# [4]	validation_0-rmse:13.21572	validation_1-rmse:14.18642
# [5]	validation_0-rmse:12.05025	validation_1-rmse:13.10497
# [6]	validation_0-rmse:11.00251	validation_1-rmse:12.14628
# [7]	validation_0-rmse:10.06259	validation_1-rmse:11.29630
# [8]	validation_0-rmse:9.22210	validation_1-rmse:10.54237
# [9]	validation_0-rmse:8.46054	validation_1-rmse:9.90385
# [10]	validation_0-rmse:7.77787	validation_1-rmse:9.34857
# [11]	validation_0-rmse:7.17249	validation_1-rmse:8.86831
# [12]	validation_0-rmse:6.61998	validation_1-rmse:8.44935
# [13]	validation_0-rmse:6.13123	validation_1-rmse:8.08936
# [14]	validation_0-rmse:5.69017	validation_1-rmse:7.76759
# [15]	validation_0-rmse:5.29514	validation_1-rmse:7.50441
# [16]	validation_0-rmse:4.94332	validation_1-rmse:7.27170
# [17]	validation_0-rmse:4.62180	validation_1-rmse:7.06060
# [18]	validation_0-rmse:4.34801	validation_1-rmse:6.90081
# [19]	validation_0-rmse:4.09080	validation_1-rmse:6.77328
# [20]	validation_0-rmse:3.86401	validation_1-rmse:6.64942
# [21]	validation_0-rmse:3.66027	validation_1-rmse:6.55777
# [22]	validation_0-rmse:3.47389	validation_1-rmse:6.48220
# [23]	validation_0-rmse:3.30886	validation_1-rmse:6.41164
# [24]	validation_0-rmse:3.15921	validation_1-rmse:6.35300
# [25]	validation_0-rmse:3.02776	validation_1-rmse:6.30014
# [26]	validation_0-rmse:2.90956	validation_1-rmse:6.24155
# [27]	validation_0-rmse:2.79284	validation_1-rmse:6.18238
# [28]	validation_0-rmse:2.69512	validation_1-rmse:6.13934
# [29]	validation_0-rmse:2.59020	validation_1-rmse:6.08530
# [30]	validation_0-rmse:2.50468	validation_1-rmse:6.05816
# [31]	validation_0-rmse:2.41662	validation_1-rmse:6.03498
# [32]	validation_0-rmse:2.35002	validation_1-rmse:6.01679
# [33]	validation_0-rmse:2.27832	validation_1-rmse:6.00581
# [34]	validation_0-rmse:2.22519	validation_1-rmse:5.99536
# [35]	validation_0-rmse:2.16685	validation_1-rmse:5.98103
# [36]	validation_0-rmse:2.11378	validation_1-rmse:5.97359
# [37]	validation_0-rmse:2.06262	validation_1-rmse:5.95850
# [38]	validation_0-rmse:2.01749	validation_1-rmse:5.95433
# [39]	validation_0-rmse:1.97905	validation_1-rmse:5.94714
# [40]	validation_0-rmse:1.93615	validation_1-rmse:5.93877
# [41]	validation_0-rmse:1.88837	validation_1-rmse:5.92604
# [42]	validation_0-rmse:1.86302	validation_1-rmse:5.91770
# [43]	validation_0-rmse:1.83713	validation_1-rmse:5.91821
# [44]	validation_0-rmse:1.81052	validation_1-rmse:5.91394
# [45]	validation_0-rmse:1.79234	validation_1-rmse:5.91026
# [46]	validation_0-rmse:1.76012	validation_1-rmse:5.90766
# [47]	validation_0-rmse:1.73751	validation_1-rmse:5.90650
# [48]	validation_0-rmse:1.70414	validation_1-rmse:5.90906
# [49]	validation_0-rmse:1.68807	validation_1-rmse:5.91148
# [50]	validation_0-rmse:1.66095	validation_1-rmse:5.90178
# [51]	validation_0-rmse:1.64257	validation_1-rmse:5.89976
# [52]	validation_0-rmse:1.61796	validation_1-rmse:5.90232
# [53]	validation_0-rmse:1.60141	validation_1-rmse:5.90191
# [54]	validation_0-rmse:1.57866	validation_1-rmse:5.90051
# [55]	validation_0-rmse:1.56263	validation_1-rmse:5.89976
# [56]	validation_0-rmse:1.55154	validation_1-rmse:5.89712
# [57]	validation_0-rmse:1.53902	validation_1-rmse:5.89688
# [58]	validation_0-rmse:1.52292	validation_1-rmse:5.89240
# [59]	validation_0-rmse:1.50752	validation_1-rmse:5.88558
# [60]	validation_0-rmse:1.49690	validation_1-rmse:5.88516
# [61]	validation_0-rmse:1.49251	validation_1-rmse:5.88338
# [62]	validation_0-rmse:1.48757	validation_1-rmse:5.88304
# [63]	validation_0-rmse:1.46844	validation_1-rmse:5.88539
# [64]	validation_0-rmse:1.46026	validation_1-rmse:5.88509
# [65]	validation_0-rmse:1.44341	validation_1-rmse:5.88427
# [66]	validation_0-rmse:1.43334	validation_1-rmse:5.88346

# %% [markdown]
# ### Evaluating predictions of the first model on test data

# %%
baseline_mae = ((abs(y_train-y_train.mean())).mean())
baseline_mae
# Out:
# 5.843002367994747

# %%
model_mae = ((abs(y_test-y_pred)).mean())
model_mae
# Out:
# 20.57656207442943

# %% [markdown]
# ### Finding the optimal parameters using GridSearch

# %%
from sklearn.model_selection import GridSearchCV
import numpy as np

# Define the parameter grid for GridSearch
param_grid = {
    "max_depth": [7],            # Reduce options
    "learning_rate": [0.05],
    "n_estimators": [300],
    "reg_alpha": [0.01, 0.05],
    "reg_lambda": [20, 30],
    "subsample": [0.8],
    "colsample_bytree": [0.8]
}

# Initialize the model
xgb_reg = XGBRegressor(objective='reg:squarederror', eval_metric="mae", random_state=42)

# Perform the grid search
grid_search = GridSearchCV(
    estimator = xgb_reg,
    param_grid = param_grid,
    scoring = 'neg_mean_squared_error',
    cv = 3,
    verbose = 1,
    n_jobs = -1
)

# Fit the grid search
grid_search.fit(X_train_transformed, y_train)

# Get the best parameters and score
print('Best Parameters: ', grid_search.best_params_)
print('Best Score:', -grid_search.best_score_)

# Use the best model to predict
best_model = grid_search.best_estimator_
y_pred = best_model.predict(X_test_transformed)
# Out:
# Fitting 3 folds for each of 4 candidates, totalling 12 fits
# Best Parameters:  {'colsample_bytree': 0.8, 'learning_rate': 0.05, 'max_depth': 7, 'n_estimators': 300, 'reg_alpha': 0.05, 'reg_lambda': 30, 'subsample': 0.8}
# Best Score: 26.068421579673743

# %% [markdown]
# ### Evaluating predictions of the grid searched model on test data

# %%
baseline_mae = ((abs(y_train-y_train.mean())).mean())
baseline_mae
# Out:
# 5.843002367994747

# %%
model_mae = ((abs(y_test-y_pred)).mean())
model_mae
# Out:
# 19.724962022848356

# %%
y_train.describe()
# Out:
# count    8563.000000
# mean       20.214898
# std         8.247430
# min         0.048396
# 25%        14.750743
# 50%        18.786913
# 75%        23.665979
# max        70.366622
# Name: consumption, dtype: float64

# %% [markdown]
# ## Feature importance and correlation matrix

# %% [markdown]
# ### Calculating feature importance

# %%
from xgboost import XGBRegressor

model = XGBRegressor()
model.fit(X_train_transformed, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
import pandas as pd

importance = model.feature_importances_
feature_names = X_train_transformed.columns
importance_df = pd.DataFrame({'Feature': feature_names, 'Importance': importance})
importance_df.sort_values(by='Importance', ascending=False, inplace=True)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20, 12))
plt.barh(importance_df['Feature'], importance_df['Importance'])
plt.gca().invert_yaxis()
plt.xlabel('Feature Importance')
plt.title('XGBoost Feature Importance')
plt.show()

# %%
importance_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 importance_df
#
# NameError: name 'importance_df' is not defined

# %% [markdown]
# ### Creating a correlation matrix

# %%
correlation_matrix = X_train_transformed.corr()

# %%
import seaborn as sns

plt.figure(figsize=(12,10))
sns.heatmap(correlation_matrix, annot=False, cmap='coolwarm')
plt.title('Feature Correlation Matrix')
plt.show()

# %%
correlated_features = set()
correlation_threshold = 0.9

for i in range(len(correlation_matrix.columns)):
    for j in range(i):
        if abs(correlation_matrix.iloc[i,j]) > correlation_threshold:
            correlated_features.add(correlation_matrix.columns[i])

# %%
correlation_matrix[['minmaxscaler__global_rad:W']].sort_values(by='minmaxscaler__global_rad:W', ascending=False)
# Out:
#                                         minmaxscaler__global_rad:W
# minmaxscaler__global_rad:W                                1.000000
# minmaxscaler__diffuse_rad:W                               0.998834
# minmaxscaler__clear_sky_rad:W                             0.998680
# minmaxscaler__direct_rad:W                                0.958581
# minmaxscaler__global_rad_1h:Wh                            0.946160
# minmaxscaler__diffuse_rad_1h:Wh                           0.943009
# minmaxscaler__clear_sky_energy_1h:J                       0.941516
# minmaxscaler__direct_rad_1h:Wh                            0.932603
# standardscaler__sun_elevation:d                           0.843238
# minmaxscaler__sunshine_duration_1h:min                    0.627275
# minmaxscaler__temp                                        0.481714
# robustscaler__t_10m:C                                     0.475080
# robustscaler__t_50m:C                                     0.448589
# robustscaler__t_100m:C                                    0.427716
# minmaxscaler__cos_wind_dir_10m:d                          0.336135
# minmaxscaler__cos_wind_dir_2m:d                           0.336135
# minmaxscaler__cos_wind_dir_50m:d                          0.325976
# minmaxscaler__dew_point_2m:C                              0.319581
# minmaxscaler__dew_point_10m:C                             0.313605
# minmaxscaler__cos_wind_dir_100m:d                         0.306304
# minmaxscaler__dew_point_50m:C                             0.293959
# minmaxscaler__dew_point_100m:C                            0.283886
# minmaxscaler__season_sine                                 0.162100
# minmaxscaler__hour_sine                                   0.114709
# minmaxscaler__sin_wind_dir_10m:d                          0.024919
# minmaxscaler__sin_wind_dir_2m:d                           0.024919
# onehotencoder__precip_type:idx_0.0                        0.020573
# minmaxscaler__sin_wind_dir_100m:d                         0.018628
# minmaxscaler__low_cloud_cover:p                           0.009053
# robustscaler__wind_speed_10m:ms                          -0.002374
# minmaxscaler__sin_wind_dir_50m:d                         -0.005845
# onehotencoder__precip_type:idx_1.0                       -0.007615
# robustscaler__wind_speed_2m:ms                           -0.010124
# onehotencoder__precip_type:idx_2.0                       -0.014947
# minmaxscaler__sin_sun_azimuth:d                          -0.016105
# minmaxscaler__precip_1h:mm                               -0.022934
# minmaxscaler__prob_precip_1h:p                           -0.027983
# onehotencoder__precip_type:idx_3.0                       -0.034285
# minmaxscaler__medium_cloud_cover:p                       -0.040931
# minmaxscaler__total_cloud_cover:p                        -0.042920
# minmaxscaler__effective_cloud_cover:p                    -0.045743
# robustscaler__wind_speed_50m:ms                          -0.058718
# minmaxscaler__month_sine                                 -0.074757
# minmaxscaler__high_cloud_cover:p                         -0.088843
# robustscaler__wind_speed_100m:ms                         -0.111964
# minmaxscaler__relative_humidity_100m:p                   -0.340011
# minmaxscaler__relative_humidity_50m:p                    -0.395442
# minmaxscaler__season_cosine                              -0.408239
# minmaxscaler__relative_humidity_10m:p                    -0.456199
# minmaxscaler__relative_humidity_2m:p                     -0.469683
# minmaxscaler__month_cosine                               -0.474940
# minmaxscaler__cos_sun_azimuth:d                          -0.631966
# minmaxscaler__hour_cosine                                -0.698855

# %%
correlated_features
# Out:
# {'minmaxscaler__clear_sky_energy_1h:J',
#  'minmaxscaler__cos_sun_azimuth:d',
#  'minmaxscaler__cos_wind_dir_100m:d',
#  'minmaxscaler__cos_wind_dir_10m:d',
#  'minmaxscaler__cos_wind_dir_50m:d',
#  'minmaxscaler__dew_point_100m:C',
#  'minmaxscaler__dew_point_10m:C',
#  'minmaxscaler__dew_point_50m:C',
#  'minmaxscaler__diffuse_rad:W',
#  'minmaxscaler__diffuse_rad_1h:Wh',
#  'minmaxscaler__direct_rad:W',
#  'minmaxscaler__direct_rad_1h:Wh',
#  'minmaxscaler__effective_cloud_cover:p',
#  'minmaxscaler__global_rad:W',
#  'minmaxscaler__global_rad_1h:Wh',
#  'minmaxscaler__prob_precip_1h:p',
#  'minmaxscaler__relative_humidity_100m:p',
#  'minmaxscaler__relative_humidity_10m:p',
#  'minmaxscaler__relative_humidity_50m:p',
#  'minmaxscaler__sin_wind_dir_10m:d',
#  'minmaxscaler__temp',
#  'onehotencoder__precip_type:idx_1.0',
#  'robustscaler__t_100m:C',
#  'robustscaler__t_10m:C',
#  'robustscaler__t_50m:C',
#  'robustscaler__wind_speed_100m:ms',
#  'robustscaler__wind_speed_10m:ms',
#  'robustscaler__wind_speed_50m:ms'}

# %%
((abs(y_test-y_pred)).mean())
# Out:
# 2.7958614410402607

# %%
((abs(y_test-y_test.mean())).mean())
# Out:
# 6.558063202750535

# %% [markdown]
# ## Plotting Features

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# List of the 5 most important features
important_features = [
    'minmaxscaler__global_rad:W',
    'minmaxscaler__direct_rad:W',
    'minmaxscaler__cos_sun_azimuth:d',
    'minmaxscaler__medium_cloud_cover:p',
    'minmaxscaler__prob_precip_1h:p'
]

# Create a scatterplot for each feature
for feature in important_features:
    plt.figure(figsize=(6, 4))  # Set figure size
    sns.scatterplot(x=X_train_transformed[feature], y=y_train)
    plt.title(f"Scatterplot of {feature} vs y_train")
    plt.xlabel(feature)
    plt.ylabel("y_train")
    #plt.xlim(0.4, None)  # Set the lower limit of the x-axis to 0.4
    plt.show()
