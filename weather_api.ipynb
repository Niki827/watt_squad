# %%
#Germany is 52.520008, and the longitude is 13.404954
import pandas as pd

# %%
# pylint: disable=missing-module-docstring

import sys
import urllib.parse
import requests

BASE_URI = "https://weather.lewagon.com"
API_KEY = 'e758951c4d37907c6eaa6b20f87e3646'

# Solar Radiation Service
# https://api.openweathermap.org/energy/1.0/solar/data?lat={lat}&lon={lon}&date={date}&appid={API key}


lat = 52.520008
lon = 13.404954
date = '2024-11-27'

url = f'https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid={API_KEY}'

#Le wagon api address
url = f'https://weather.lewagon.com/data/2.5/weather?lat={lat}&lon={lon}&date={date}'

print(url)
response = requests.get(url)
# if response.status_code != 200:
#     return 'status code 200'
#data = response.json()


#api_data = requests.get(url).json()

#df = pd.DataFrame(api_data['results'])
# Out:
# https://weather.lewagon.com/data/2.5/weather?lat=52.520008&lon=13.404954&date=2024-11-27
# <Response [200]>

# %%
# # pylint: disable=missing-module-docstring

# import sys
# import urllib.parse
# import requests

# BASE_URI = "https://weather.lewagon.com"
# #API_KEY = 'c87357a5f0edba71495f2630c668c3af'
# API_KEY = 'e758951c4d37907c6eaa6b20f87e3646'
# # Solar Radiation Service
# https://api.openweathermap.org/energy/1.0/solar/data?lat=34&lon=34&date=2023-03-28&appid=e758951c4d37907c6eaa6b20f87e3646
# # https://api.openweathermap.org/energy/1.0/solar/data?lat={lat}&lon={lon}&date={date}&appid={API key}


# lat = 52.520008
# lon = 13.404954
# date = '2024-11-29'

# #url = f'https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid={API_KEY}'

# # solar radiation
# url= f'https://api.openweathermap.org/energy/1.0/solar/data?lat={lat}&lon={lon}&date={date}&appid={API_KEY}'



# # url = f'https://weather.lewagon.com/data/2.5/weather?lat={lat}&lon={lon}&date={date}'

# print(url)
# response = requests.get(url)

# # if response.status_code != 200:
# #     return 'status code 200'
# data = response.json()

# data
# #api_data = requests.get(url).json()

# #df = pd.DataFrame(api_data['results'])
# Out:
# https://api.openweathermap.org/energy/1.0/solar/data?lat=52.520008&lon=13.404954&date=2024-11-29&appid=e758951c4d37907c6eaa6b20f87e3646
# {'cod': 401,
#  'message': 'Invalid API key. Please see https://openweathermap.org/faq#error401 for more info.'}

# %% [markdown]
# # Solar Radiation API

# %%
import json

# JSON data from API CALL https://api.openweathermap.org/energy/1.0/solar/data?lat=52.520008&lon=13.404954&date=2024-11-29&appid='API_KEY'
json_data = {
   "lat":34,
   "lon":34,
   "date":"2023-03-28",
   "tz":"+02:00",
   "sunrise":"2023-03-28T05:37:14",
   "sunset":"2023-03-28T18:01:37",
   "irradiance":{
      "daily":[
         {
            "clear_sky":{
               "ghi":6689.07,
               "dni":9138,
               "dhi":1139.39
            },
            "cloudy_sky":{
               "ghi":6134.92,
               "dni":6847.35,
               "dhi":1590.34
            }
         }
      ],
      "hourly":[
         {
            "hour":0,
            "clear_sky":{
               "ghi":0,
               "dni":0,
               "dhi":0
            },
            "cloudy_sky":{
               "ghi":0,
               "dni":0,
               "dhi":0
            }
         },
         {
            "hour":1,
            "clear_sky":{
               "ghi":0,
               "dni":0,
               "dhi":0
            },
            "cloudy_sky":{
               "ghi":0,
               "dni":0,
               "dhi":0
            }
         },
         {
            "hour":2,
            "clear_sky":{
               "ghi":0,
               "dni":0,
               "dhi":0
            },
            "cloudy_sky":{
               "ghi":0,
               "dni":0,
               "dhi":0
            }
         },
         {
            "hour":3,
            "clear_sky":{
               "ghi":0,
               "dni":0,
               "dhi":0
            },
            "cloudy_sky":{
               "ghi":0,
               "dni":0,
               "dhi":0
            }
         },
         {
            "hour":4,
            "clear_sky":{
               "ghi":0,
               "dni":0,
               "dhi":0
            },
            "cloudy_sky":{
               "ghi":0,
               "dni":0,
               "dhi":0
            }
         },
         {
            "hour":5,
            "clear_sky":{
               "ghi":4.43,
               "dni":35.71,
               "dhi":5.22
            },
            "cloudy_sky":{
               "ghi":3.04,
               "dni":0,
               "dhi":3.04
            }
         },
         {
            "hour":6,
            "clear_sky":{
               "ghi":130.19,
               "dni":462.12,
               "dhi":52.16
            },
            "cloudy_sky":{
               "ghi":87.4,
               "dni":106.87,
               "dhi":64.73
            }
         },
         {
            "hour":7,
            "clear_sky":{
               "ghi":343.69,
               "dni":701.54,
               "dhi":81.8
            },
            "cloudy_sky":{
               "ghi":215.38,
               "dni":153.97,
               "dhi":160.27
            }
         },
         {
            "hour":8,
            "clear_sky":{
               "ghi":551.8,
               "dni":814.96,
               "dhi":99.89
            },
            "cloudy_sky":{
               "ghi":326.46,
               "dni":116.44,
               "dhi":257.9
            }
         },
         {
            "hour":9,
            "clear_sky":{
               "ghi":725.54,
               "dni":878.31,
               "dhi":111.61
            },
            "cloudy_sky":{
               "ghi":598.51,
               "dni":441.13,
               "dhi":283.46
            }
         },
         {
            "hour":10,
            "clear_sky":{
               "ghi":846.65,
               "dni":913.11,
               "dhi":118.64
            },
            "cloudy_sky":{
               "ghi":817.44,
               "dni":816.77,
               "dhi":157.58
            }
         },
         {
            "hour":11,
            "clear_sky":{
               "ghi":903.59,
               "dni":927.57,
               "dhi":121.7
            },
            "cloudy_sky":{
               "ghi":903.54,
               "dni":909.19,
               "dhi":129.15
            }
         },
         {
            "hour":12,
            "clear_sky":{
               "ghi":891.14,
               "dni":924.52,
               "dhi":121.04
            },
            "cloudy_sky":{
               "ghi":891.13,
               "dni":908.75,
               "dhi":126.25
            }
         },
         {
            "hour":13,
            "clear_sky":{
               "ghi":810.46,
               "dni":903.39,
               "dhi":116.6
            },
            "cloudy_sky":{
               "ghi":810.46,
               "dni":895.82,
               "dhi":114.71
            }
         },
         {
            "hour":14,
            "clear_sky":{
               "ghi":669.04,
               "dni":859.85,
               "dhi":108.01
            },
            "cloudy_sky":{
               "ghi":669.02,
               "dni":854.19,
               "dhi":104.93
            }
         },
         {
            "hour":15,
            "clear_sky":{
               "ghi":480.7,
               "dni":782.44,
               "dhi":94.32
            },
            "cloudy_sky":{
               "ghi":480.69,
               "dni":775.6,
               "dhi":91.19
            }
         },
         {
            "hour":16,
            "clear_sky":{
               "ghi":266.56,
               "dni":639.38,
               "dhi":73.14
            },
            "cloudy_sky":{
               "ghi":266.56,
               "dni":639.96,
               "dhi":65.07
            }
         },
         {
            "hour":17,
            "clear_sky":{
               "ghi":65.28,
               "dni":295.1,
               "dhi":35.25
            },
            "cloudy_sky":{
               "ghi":65.28,
               "dni":228.66,
               "dhi":32.06
            }
         },
         {
            "hour":18,
            "clear_sky":{
               "ghi":0,
               "dni":0,
               "dhi":0
            },
            "cloudy_sky":{
               "ghi":0,
               "dni":0,
               "dhi":0
            }
         },
         {
            "hour":19,
            "clear_sky":{
               "ghi":0,
               "dni":0,
               "dhi":0
            },
            "cloudy_sky":{
               "ghi":0,
               "dni":0,
               "dhi":0
            }
         },
         {
            "hour":20,
            "clear_sky":{
               "ghi":0,
               "dni":0,
               "dhi":0
            },
            "cloudy_sky":{
               "ghi":0,
               "dni":0,
               "dhi":0
            }
         },
         {
            "hour":21,
            "clear_sky":{
               "ghi":0,
               "dni":0,
               "dhi":0
            },
            "cloudy_sky":{
               "ghi":0,
               "dni":0,
               "dhi":0
            }
         },
         {
            "hour":22,
            "clear_sky":{
               "ghi":0,
               "dni":0,
               "dhi":0
            },
            "cloudy_sky":{
               "ghi":0,
               "dni":0,
               "dhi":0
            }
         },
         {
            "hour":23,
            "clear_sky":{
               "ghi":0,
               "dni":0,
               "dhi":0
            },
            "cloudy_sky":{
               "ghi":0,
               "dni":0,
               "dhi":0
            }
         }
      ]
   }
}
# Save to a JSON file
with open("solar_data.json", "w") as file:
    json.dump(json_data, file, indent=4)

print("Data has been saved to solar_data.json")
# Out:
# Data has been saved to solar_data.json

# %%
# Open and load the JSON file
with open("raw_data/solar_data.json", "r") as file:
    data = json.load(file)

# Access the data as a Python object
print(type(data))
# Out:
# <class 'dict'>

# %%
# Navigate to the 'clear_sky' GHI value
clear_sky_ghi = data["irradiance"]["daily"][0]["clear_sky"]["ghi"]
clear_sky_dni = data['irradiance']['daily'][0]['clear_sky']['dni']
clear_sky_dhi = data['irradiance']['daily'][0]['clear_sky']['dhi']
rad_date = json_data['date']

print("Radiation for Date:", rad_date)
print("Clear Sky GHI:", clear_sky_ghi)
print("Clear Sky DNI:", clear_sky_dni)
print("Clear Sky DHI:", clear_sky_dhi)
# Out:
# Radiation for Date: 2023-03-28
# Clear Sky GHI: 6689.07
# Clear Sky DNI: 9138
# Clear Sky DHI: 1139.39

# %%
data
# Out:
# {'lat': 34,
#  'lon': 34,
#  'date': '2023-03-28',
#  'tz': '+02:00',
#  'sunrise': '2023-03-28T05:37:14',
#  'sunset': '2023-03-28T18:01:37',
#  'irradiance': {'daily': [{'clear_sky': {'ghi': 6689.07,
#      'dni': 9138,
#      'dhi': 1139.39},
#     'cloudy_sky': {'ghi': 6134.92, 'dni': 6847.35, 'dhi': 1590.34}}],
#   'hourly': [{'hour': 0,
#     'clear_sky': {'ghi': 0, 'dni': 0, 'dhi': 0},
#     'cloudy_sky': {'ghi': 0, 'dni': 0, 'dhi': 0}},
#    {'hour': 1,
#     'clear_sky': {'ghi': 0, 'dni': 0, 'dhi': 0},
#     'cloudy_sky': {'ghi': 0, 'dni': 0, 'dhi': 0}},
#    {'hour': 2,
#     'clear_sky': {'ghi': 0, 'dni': 0, 'dhi': 0},
#     'cloudy_sky': {'ghi': 0, 'dni': 0, 'dhi': 0}},
#    {'hour': 3,
#     'clear_sky': {'ghi': 0, 'dni': 0, 'dhi': 0},
#     'cloudy_sky': {'ghi': 0, 'dni': 0, 'dhi': 0}},
#    {'hour': 4,
#     'clear_sky': {'ghi': 0, 'dni': 0, 'dhi': 0},
#     'cloudy_sky': {'ghi': 0, 'dni': 0, 'dhi': 0}},
#    {'hour': 5,
# ...

# %% [markdown]
# # Current Weather API

# %%
# pylint: disable=missing-module-docstring

import sys
import urllib.parse
import requests

#BASE_URI = "https://weather.lewagon.com"
BSE_URI = ' https://api.openweathermap.org'
# https://api.openweathermap.org/energy/1.0/solar/data?lat={lat}&lon={lon}&date={date}&appid={API key}


lat = 52.520008
lon = 13.404954
date = '2024-11-29'

#url = f'https://weather.lewagon.com/data/2.5/weather?lat={lat}&lon={lon}&date={date}&unit=metric'

url = urllib.parse.urljoin(BASE_URI, "/data/2.5/weather?")
print(lat, lon)
forecasts = requests.get(BASE_URI, params={'lat': lat, 'lon': lon, 'units': 'metric'}).json()
print(url)
current_weather_data = requests.get(url).json()

current_weather_data
#api_data = requests.get(url).json()
# Out:
# 52.520008 13.404954
# https://weather.lewagon.com/data/2.5/weather
# {'error': 'Please specify both `lat` and `lon` as float parameters',
#  'example': 'https://weather.lewagon.com/data/2.5/weather?lat=48.8588897&lon=2.3200410217200766'}

# %%
current_weather_data['main']['temp']
# Out:
# 278.95
